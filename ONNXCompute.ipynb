# %%
from google.colab import drive
drive.mount('/content/gdrive')
workspace = '/content/gdrive/MyDrive/ONNXAnalyser/onnx_models'
# Out:
# Mounted at /content/gdrive

# %%
# !pip install onnx numpy
# !pip install onnxruntime
# !pip install plotly==4.14.3
# !pip install kaleido
# Out:
# Collecting onnx
#   Downloading onnx-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 28.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.22.4)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.10/dist-packages (from onnx) (4.7.1)
# Installing collected packages: onnx
# Successfully installed onnx-1.14.0
# Collecting onnxruntime
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 13.6 MB/s eta 0:00:00
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (23.5.26)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (23.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (1.11.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime) (1.3.0)
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.15.1
# Collecting plotly==4.14.3
#   Downloading plotly-4.14.3-py2.py3-none-any.whl (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 77.3 MB/s eta 0:00:00
# Collecting retrying>=1.3.3 (from plotly==4.14.3)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from plotly==4.14.3) (1.16.0)
# Installing collected packages: retrying, plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.13.1
#     Uninstalling plotly-5.13.1:
#       Successfully uninstalled plotly-5.13.1
# Successfully installed plotly-4.14.3 retrying-1.3.4
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.2 MB/s eta 0:00:00
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1

# %%
import onnx
import onnx.shape_inference
import numpy as np
from collections import defaultdict

# Dictionary to store initializer tensors and their shapes
initializer_dict = {}

def print_model_compute(model_path):
    model = onnx.load(model_path)
    # Perform shape inference on the model
    inferred_model = onnx.shape_inference.infer_shapes(model)

    graph = inferred_model.graph

    for initializer in model.graph.initializer:
        initializer_dict[initializer.name] = tuple(d for d in initializer.dims)

    # print("Input Parameters:")
    # for input_param in graph.input:
    #     name = input_param.name
    #     shape = get_shape(graph, name)
    #     dtype = input_param.type.tensor_type.elem_type
    #     print(f"Name: {name}, Shape: {shape}, Data Type: {dtype}")

    total_flops = 0
    model_summary = defaultdict(int)
    print("\nLayer Dimensions:")
    for i, node in enumerate(graph.node):
        op_type = node.op_type
        output_name = node.output[0]
        model_summary[op_type] += 1
        if op_type == 'Conv':
            input_name = node.input[0]
            input_weight = node.input[1]
            input_shape = get_shape(graph, input_name)
            weight_shape = get_shape(graph, input_weight)
            output_shape = get_shape(graph, output_name)
            # print(node.attribute)
            # kernel_shape = node.attribute[2].ints
            for attribute in node.attribute:
              if attribute.name == 'kernel_shape':
                kernel_shape = attribute.ints
              if attribute.name == 'strides':
                stride_shape = attribute.ints
            # stride_shape = [attribute.ints for attribute in node.attribute if attribute.name == 'strides']
            # print(stride_shape)
            # stride_shape = node.attribute[4].ints
            # input dimensions
            C_in = input_shape[1]
            # output dimensions
            C_out = output_shape[1]
            H_out = output_shape[2]
            W_out = output_shape[3]
            # kernel dimensions
            H_k = kernel_shape[0]
            W_k = kernel_shape[1]
            # stride
            stride = stride_shape[0]
            # compute flops
            flops = C_in * H_out * W_out  * C_out * H_k * W_k / (stride * stride)
            total_flops += flops
            print(f"{i} Conv Layer: Input Shape: {input_shape}, weight: {weight_shape}, Output Shape: {output_shape}, flops: {flops}")

        elif op_type == 'Gemm':
            input_name = node.input[0]
            input_weight = node.input[1]
            input_shape = get_shape(graph, input_name)
            weight_shape = get_shape(graph, input_weight)
            output_shape = get_shape(graph, output_name)
            N_in = input_shape[1]
            H_w, W_w = weight_shape[0], weight_shape[1]
            flops = N_in * H_w * W_w
            total_flops += flops
            print(f"{i} Gemm {input_name} Layer: Input Shape: {input_shape}, weight: {weight_shape}, Output Shape: {output_shape}, flops: {flops}")

        elif op_type == 'AveragePool':
            input_name = node.input[0]
            input_shape = get_shape(graph, input_name)
            output_shape = get_shape(graph, output_name)
            kernel_shape = node.attribute[1].ints
            C_in = input_shape[1]
            H_out = output_shape[2]
            W_out = output_shape[3]
            H_k = kernel_shape[0]
            W_k = kernel_shape[1]
            flops = C_in * H_out * W_out * H_k * W_k
            total_flops += flops
            print(f"{i} AveragePool {input_name} Layer: Input Shape: {input_shape}, Output Shape: {output_shape}, flops: {flops}")

        elif op_type == 'GlobalAveragePool':
            input_name = node.input[0]
            input_shape = get_shape(graph, input_name)
            output_shape = get_shape(graph, output_name)
            C_in = input_shape[1]
            H_in = input_shape[2]
            W_in = input_shape[3]
            H_out = output_shape[2]
            W_out = output_shape[3]
            flops = C_in * H_out * W_out * H_in * W_in
            total_flops += flops
            print(f"{i} GlobalAveragePool {input_name} Layer: Input Shape: {input_shape}, Output Shape: {output_shape}, flops: {flops}")

        elif op_type == 'Add':
            input1_name = node.input[0]
            input2_name = node.input[1]
            input1_shape = get_shape(graph, input1_name)
            input2_shape = get_shape(graph, input2_name)
            output_shape = get_shape(graph, output_name)
            C = input_shape[1]
            H = input_shape[2]
            W = input_shape[3]
            flops = C * H * W
            total_flops += flops
            print(f"{i} Add Layer: Input1 Shape: {input1_shape}, Input2 Shape: {input2_shape}, Output Shape: {output_shape}, flops: {flops}")

        elif op_type == 'MatMul':
            input1_name = node.input[0]
            input2_name = node.input[1]
            input1_shape = get_shape(graph, input1_name)
            input2_shape = get_shape(graph, input2_name)
            output_shape = get_shape(graph, output_name)
            H_in, W_in = input_shape[0], input_shape[1]
            H_out, W_out = output_shape[0], output_shape[1]
            flops = H_in * W_in * H_out * W_out
            total_flops += flops
            print(f"{i} MatMul Layer: Input1 Shape: {input1_shape}, Input2 Shape: {input2_shape}, Output Shape: {output_shape}, flops: {flops}")
    # print model summary
    total_operations = 0
    print("model summary: {}".format(model_path))
    for op_type, op_num in model_summary.items():
      print("{}: {}".format(op_type, op_num))
      total_operations += op_num
    print("total operations: {}".format(total_operations))
    return total_flops

def get_shape(graph, name):
    for input_param in graph.input:
        if input_param.name == name:
            shape = [dim.dim_value for dim in input_param.type.tensor_type.shape.dim]
            # print('input_param:', input_param)
            return shape
    for value_info in graph.value_info:
        if value_info.name == name:
            shape = [dim.dim_value for dim in value_info.type.tensor_type.shape.dim]
            # print('value_info:', value_info)
            if len(shape) != 0:
              return shape
    for output_param in graph.output:
        if output_param.name == name:
            shape = [dim.dim_value for dim in output_param.type.tensor_type.shape.dim]
            # print('output_param:', output_param)
            return shape

    if name in initializer_dict:
        weight = initializer_dict[name]
        # print('initializer_dict:', weight)
        return weight

    return None

# Path to the ONNX model file
model_path = workspace + '/mobilenetv2-7.onnx'

# Print input parameters and layer dimensions
print_model_compute(model_path)
# Out:
# Layer Dimensions:
# 0 Conv Layer: Input Shape: [1, 3, 224, 224], weight: [32, 3, 3, 3], Output Shape: [1, 32, 112, 112], flops: 2709504.0
# 3 Conv Layer: Input Shape: [1, 32, 112, 112], weight: [32, 32, 1, 1], Output Shape: [1, 32, 112, 112], flops: 12845056.0
# 6 Conv Layer: Input Shape: [1, 32, 112, 112], weight: [32, 1, 3, 3], Output Shape: [1, 32, 112, 112], flops: 115605504.0
# 9 Conv Layer: Input Shape: [1, 32, 112, 112], weight: [16, 32, 1, 1], Output Shape: [1, 16, 112, 112], flops: 6422528.0
# 11 Conv Layer: Input Shape: [1, 16, 112, 112], weight: [96, 16, 1, 1], Output Shape: [1, 96, 112, 112], flops: 19267584.0
# 14 Conv Layer: Input Shape: [1, 96, 112, 112], weight: [96, 1, 3, 3], Output Shape: [1, 96, 56, 56], flops: 65028096.0
# 17 Conv Layer: Input Shape: [1, 96, 56, 56], weight: [24, 96, 1, 1], Output Shape: [1, 24, 56, 56], flops: 7225344.0
# 19 Conv Layer: Input Shape: [1, 24, 56, 56], weight: [144, 24, 1, 1], Output Shape: [1, 144, 56, 56], flops: 10838016.0
# 22 Conv Layer: Input Shape: [1, 144, 56, 56], weight: [144, 1, 3, 3], Output Shape: [1, 144, 56, 56], flops: 585252864.0
# 25 Conv Layer: Input Shape: [1, 144, 56, 56], weight: [24, 144, 1, 1], Output Shape: [1, 24, 56, 56], flops: 10838016.0
# 27 Add Layer: Input1 Shape: [1, 24, 56, 56], Input2 Shape: [1, 24, 56, 56], Output Shape: [1, 24, 56, 56], flops: 451584
# 28 Conv Layer: Input Shape: [1, 24, 56, 56], weight: [144, 24, 1, 1], Output Shape: [1, 144, 56, 56], flops: 10838016.0
# 31 Conv Layer: Input Shape: [1, 144, 56, 56], weight: [144, 1, 3, 3], Output Shape: [1, 144, 28, 28], flops: 36578304.0
# 34 Conv Layer: Input Shape: [1, 144, 28, 28], weight: [32, 144, 1, 1], Output Shape: [1, 32, 28, 28], flops: 3612672.0
# 36 Conv Layer: Input Shape: [1, 32, 28, 28], weight: [192, 32, 1, 1], Output Shape: [1, 192, 28, 28], flops: 4816896.0
# 39 Conv Layer: Input Shape: [1, 192, 28, 28], weight: [192, 1, 3, 3], Output Shape: [1, 192, 28, 28], flops: 260112384.0
# 42 Conv Layer: Input Shape: [1, 192, 28, 28], weight: [32, 192, 1, 1], Output Shape: [1, 32, 28, 28], flops: 4816896.0
# 44 Add Layer: Input1 Shape: [1, 32, 28, 28], Input2 Shape: [1, 32, 28, 28], Output Shape: [1, 32, 28, 28], flops: 150528
# 45 Conv Layer: Input Shape: [1, 32, 28, 28], weight: [192, 32, 1, 1], Output Shape: [1, 192, 28, 28], flops: 4816896.0
# 48 Conv Layer: Input Shape: [1, 192, 28, 28], weight: [192, 1, 3, 3], Output Shape: [1, 192, 28, 28], flops: 260112384.0
# 51 Conv Layer: Input Shape: [1, 192, 28, 28], weight: [32, 192, 1, 1], Output Shape: [1, 32, 28, 28], flops: 4816896.0
# 53 Add Layer: Input1 Shape: [1, 32, 28, 28], Input2 Shape: [1, 32, 28, 28], Output Shape: [1, 32, 28, 28], flops: 150528
# 54 Conv Layer: Input Shape: [1, 32, 28, 28], weight: [192, 32, 1, 1], Output Shape: [1, 192, 28, 28], flops: 4816896.0
# 57 Conv Layer: Input Shape: [1, 192, 28, 28], weight: [192, 1, 3, 3], Output Shape: [1, 192, 28, 28], flops: 260112384.0
# 60 Conv Layer: Input Shape: [1, 192, 28, 28], weight: [64, 192, 1, 1], Output Shape: [1, 64, 28, 28], flops: 9633792.0
# 62 Conv Layer: Input Shape: [1, 64, 28, 28], weight: [384, 64, 1, 1], Output Shape: [1, 384, 28, 28], flops: 19267584.0
# 65 Conv Layer: Input Shape: [1, 384, 28, 28], weight: [384, 1, 3, 3], Output Shape: [1, 384, 28, 28], flops: 1040449536.0
# 68 Conv Layer: Input Shape: [1, 384, 28, 28], weight: [64, 384, 1, 1], Output Shape: [1, 64, 28, 28], flops: 19267584.0
# 70 Add Layer: Input1 Shape: [1, 64, 28, 28], Input2 Shape: [1, 64, 28, 28], Output Shape: [1, 64, 28, 28], flops: 301056
# 71 Conv Layer: Input Shape: [1, 64, 28, 28], weight: [384, 64, 1, 1], Output Shape: [1, 384, 28, 28], flops: 19267584.0
# 74 Conv Layer: Input Shape: [1, 384, 28, 28], weight: [384, 1, 3, 3], Output Shape: [1, 384, 28, 28], flops: 1040449536.0
# 77 Conv Layer: Input Shape: [1, 384, 28, 28], weight: [64, 384, 1, 1], Output Shape: [1, 64, 28, 28], flops: 19267584.0
# 79 Add Layer: Input1 Shape: [1, 64, 28, 28], Input2 Shape: [1, 64, 28, 28], Output Shape: [1, 64, 28, 28], flops: 301056
# 80 Conv Layer: Input Shape: [1, 64, 28, 28], weight: [384, 64, 1, 1], Output Shape: [1, 384, 28, 28], flops: 19267584.0
# 83 Conv Layer: Input Shape: [1, 384, 28, 28], weight: [384, 1, 3, 3], Output Shape: [1, 384, 28, 28], flops: 1040449536.0
# 86 Conv Layer: Input Shape: [1, 384, 28, 28], weight: [64, 384, 1, 1], Output Shape: [1, 64, 28, 28], flops: 19267584.0
# 88 Add Layer: Input1 Shape: [1, 64, 28, 28], Input2 Shape: [1, 64, 28, 28], Output Shape: [1, 64, 28, 28], flops: 301056
# 89 Conv Layer: Input Shape: [1, 64, 28, 28], weight: [384, 64, 1, 1], Output Shape: [1, 384, 28, 28], flops: 19267584.0
# 92 Conv Layer: Input Shape: [1, 384, 28, 28], weight: [384, 1, 3, 3], Output Shape: [1, 384, 14, 14], flops: 65028096.0
# 95 Conv Layer: Input Shape: [1, 384, 14, 14], weight: [96, 384, 1, 1], Output Shape: [1, 96, 14, 14], flops: 7225344.0
# 97 Conv Layer: Input Shape: [1, 96, 14, 14], weight: [576, 96, 1, 1], Output Shape: [1, 576, 14, 14], flops: 10838016.0
# 100 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [576, 1, 3, 3], Output Shape: [1, 576, 14, 14], flops: 585252864.0
# 103 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [96, 576, 1, 1], Output Shape: [1, 96, 14, 14], flops: 10838016.0
# 105 Add Layer: Input1 Shape: [1, 96, 14, 14], Input2 Shape: [1, 96, 14, 14], Output Shape: [1, 96, 14, 14], flops: 112896
# 106 Conv Layer: Input Shape: [1, 96, 14, 14], weight: [576, 96, 1, 1], Output Shape: [1, 576, 14, 14], flops: 10838016.0
# 109 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [576, 1, 3, 3], Output Shape: [1, 576, 14, 14], flops: 585252864.0
# 112 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [96, 576, 1, 1], Output Shape: [1, 96, 14, 14], flops: 10838016.0
# 114 Add Layer: Input1 Shape: [1, 96, 14, 14], Input2 Shape: [1, 96, 14, 14], Output Shape: [1, 96, 14, 14], flops: 112896
# 115 Conv Layer: Input Shape: [1, 96, 14, 14], weight: [576, 96, 1, 1], Output Shape: [1, 576, 14, 14], flops: 10838016.0
# 118 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [576, 1, 3, 3], Output Shape: [1, 576, 7, 7], flops: 36578304.0
# 121 Conv Layer: Input Shape: [1, 576, 7, 7], weight: [160, 576, 1, 1], Output Shape: [1, 160, 7, 7], flops: 4515840.0
# 123 Conv Layer: Input Shape: [1, 160, 7, 7], weight: [960, 160, 1, 1], Output Shape: [1, 960, 7, 7], flops: 7526400.0
# 126 Conv Layer: Input Shape: [1, 960, 7, 7], weight: [960, 1, 3, 3], Output Shape: [1, 960, 7, 7], flops: 406425600.0
# 129 Conv Layer: Input Shape: [1, 960, 7, 7], weight: [160, 960, 1, 1], Output Shape: [1, 160, 7, 7], flops: 7526400.0
# 131 Add Layer: Input1 Shape: [1, 160, 7, 7], Input2 Shape: [1, 160, 7, 7], Output Shape: [1, 160, 7, 7], flops: 47040
# 132 Conv Layer: Input Shape: [1, 160, 7, 7], weight: [960, 160, 1, 1], Output Shape: [1, 960, 7, 7], flops: 7526400.0
# 135 Conv Layer: Input Shape: [1, 960, 7, 7], weight: [960, 1, 3, 3], Output Shape: [1, 960, 7, 7], flops: 406425600.0
# 138 Conv Layer: Input Shape: [1, 960, 7, 7], weight: [160, 960, 1, 1], Output Shape: [1, 160, 7, 7], flops: 7526400.0
# 140 Add Layer: Input1 Shape: [1, 160, 7, 7], Input2 Shape: [1, 160, 7, 7], Output Shape: [1, 160, 7, 7], flops: 47040
# 141 Conv Layer: Input Shape: [1, 160, 7, 7], weight: [960, 160, 1, 1], Output Shape: [1, 960, 7, 7], flops: 7526400.0
# 144 Conv Layer: Input Shape: [1, 960, 7, 7], weight: [960, 1, 3, 3], Output Shape: [1, 960, 7, 7], flops: 406425600.0
# 147 Conv Layer: Input Shape: [1, 960, 7, 7], weight: [320, 960, 1, 1], Output Shape: [1, 320, 7, 7], flops: 15052800.0
# 149 Conv Layer: Input Shape: [1, 320, 7, 7], weight: [1280, 320, 1, 1], Output Shape: [1, 1280, 7, 7], flops: 20070400.0
# 152 GlobalAveragePool mobilenetv20_features_relu1_fwd Layer: Input Shape: [1, 1280, 7, 7], Output Shape: [1, 1280, 1, 1], flops: 62720
# 153 Conv Layer: Input Shape: [1, 1280, 1, 1], weight: [1000, 1280, 1, 1], Output Shape: [1, 1000, 1, 1], flops: 1280000.0
# model summary: /content/gdrive/MyDrive/ONNXAnalyser/onnx_models/mobilenetv2-7.onnx
# Conv: 54
# BatchNormalization: 53
# Relu: 36
# Add: 10
# GlobalAveragePool: 1
# Reshape: 1
# total operations: 155
# 7590732416.0

# %%
import os
onnx_models = os.listdir(workspace)

compute_estimate = {}

onnx_models = ['bvlcalexnet-12.onnx','vgg16-12.onnx','vgg19-7.onnx', 'inception-v1-12.onnx', 'inception-v2-9.onnx',
               'googlenet-12.onnx','resnet18-v1-7.onnx', 'resnet34-v1-7.onnx', 'resnet50-v1-7.onnx', 'resnet101-v1-7.onnx', 'resnet152-v1-7.onnx',
               'densenet-9.onnx', 'squeezenet1.0-12.onnx', 'mobilenetv2-7.onnx', 'shufflenet-v2-10.onnx', 'efficientnet-lite4-11.onnx']

# error: 'inception-v1-3.onnx',

for onnx_model in onnx_models:
  # Path to the ONNX model file
  if 'onnx' not in onnx_model: # or 'vgg' in onnx_model:
    continue
  print('Model:', onnx_model)
  model_path = workspace + '/' + onnx_model
  # Input data as a NumPy array
  input_data = np.random.randn(1, 3, 224, 224).astype(np.float32)  # Adjust the shape and data type as per your model's input requirements
  # Print intermediate results
  compute_estimate[onnx_model[:-5]] = print_model_compute(model_path)
# Out:
# Model: bvlcalexnet-12.onnx
#
# Layer Dimensions:
# 0 Conv Layer: Input Shape: [1, 3, 224, 224], weight: (96, 3, 11, 11), Output Shape: [1, 96, 54, 54], flops: 6351048.0
# 4 Conv Layer: Input Shape: [1, 96, 26, 26], weight: (256, 48, 5, 5), Output Shape: [1, 256, 26, 26], flops: 415334400.0
# 8 Conv Layer: Input Shape: [1, 256, 12, 12], weight: (384, 256, 3, 3), Output Shape: [1, 384, 12, 12], flops: 127401984.0
# 10 Conv Layer: Input Shape: [1, 384, 12, 12], weight: (384, 192, 3, 3), Output Shape: [1, 384, 12, 12], flops: 191102976.0
# 12 Conv Layer: Input Shape: [1, 384, 12, 12], weight: (256, 192, 3, 3), Output Shape: [1, 256, 12, 12], flops: 127401984.0
# 16 Gemm OC2_DUMMY_0 Layer: Input Shape: [1, 9216], weight: (4096, 9216), Output Shape: [1, 4096], flops: 347892350976
# 19 Gemm fc6_3 Layer: Input Shape: [1, 4096], weight: (4096, 4096), Output Shape: [1, 4096], flops: 68719476736
# 22 Gemm fc7_3 Layer: Input Shape: [1, 4096], weight: (1000, 4096), Output Shape: [1, 1000], flops: 16777216000
# model summary: /content/gdrive/MyDrive/ONNXAnalyser/onnx_models/bvlcalexnet-12.onnx
# Conv: 5
# Relu: 7
# LRN: 2
# MaxPool: 3
# Reshape: 1
# Gemm: 3
# Dropout: 2
# Softmax: 1
# total operations: 24
# Model: vgg16-12.onnx
#
# Layer Dimensions:
# 0 Conv Layer: Input Shape: [1, 3, 224, 224], weight: (64, 3, 3, 3), Output Shape: [1, 64, 224, 224], flops: 86704128.0
# 2 Conv Layer: Input Shape: [1, 64, 224, 224], weight: (64, 64, 3, 3), Output Shape: [1, 64, 224, 224], flops: 1849688064.0
# 5 Conv Layer: Input Shape: [1, 64, 112, 112], weight: (128, 64, 3, 3), Output Shape: [1, 128, 112, 112], flops: 924844032.0
# 7 Conv Layer: Input Shape: [1, 128, 112, 112], weight: (128, 128, 3, 3), Output Shape: [1, 128, 112, 112], flops: 1849688064.0
# 10 Conv Layer: Input Shape: [1, 128, 56, 56], weight: (256, 128, 3, 3), Output Shape: [1, 256, 56, 56], flops: 924844032.0
# 12 Conv Layer: Input Shape: [1, 256, 56, 56], weight: (256, 256, 3, 3), Output Shape: [1, 256, 56, 56], flops: 1849688064.0
# 14 Conv Layer: Input Shape: [1, 256, 56, 56], weight: (256, 256, 3, 3), Output Shape: [1, 256, 56, 56], flops: 1849688064.0
# 17 Conv Layer: Input Shape: [1, 256, 28, 28], weight: (512, 256, 3, 3), Output Shape: [1, 512, 28, 28], flops: 924844032.0
# 19 Conv Layer: Input Shape: [1, 512, 28, 28], weight: (512, 512, 3, 3), Output Shape: [1, 512, 28, 28], flops: 1849688064.0
# 21 Conv Layer: Input Shape: [1, 512, 28, 28], weight: (512, 512, 3, 3), Output Shape: [1, 512, 28, 28], flops: 1849688064.0
# 24 Conv Layer: Input Shape: [1, 512, 14, 14], weight: (512, 512, 3, 3), Output Shape: [1, 512, 14, 14], flops: 462422016.0
# 26 Conv Layer: Input Shape: [1, 512, 14, 14], weight: (512, 512, 3, 3), Output Shape: [1, 512, 14, 14], flops: 462422016.0
# 28 Conv Layer: Input Shape: [1, 512, 14, 14], weight: (512, 512, 3, 3), Output Shape: [1, 512, 14, 14], flops: 462422016.0
# 32 Gemm flatten_60 Layer: Input Shape: [1, 25088], weight: (4096, 25088), Output Shape: [1, 4096], flops: 2578054119424
# 36 Gemm flatten_65 Layer: Input Shape: [1, 4096], weight: (4096, 4096), Output Shape: [1, 4096], flops: 68719476736
# 40 Gemm flatten_70 Layer: Input Shape: [1, 4096], weight: (1000, 4096), Output Shape: [1, 1000], flops: 16777216000
# model summary: /content/gdrive/MyDrive/ONNXAnalyser/onnx_models/vgg16-12.onnx
# Conv: 13
# Relu: 15
# MaxPool: 5
# Flatten: 3
# Gemm: 3
# Dropout: 2
# total operations: 41
# Model: vgg19-7.onnx
#
# Layer Dimensions:
# 0 Conv Layer: Input Shape: [1, 3, 224, 224], weight: [64, 3, 3, 3], Output Shape: [1, 64, 224, 224], flops: 86704128.0
# 2 Conv Layer: Input Shape: [1, 64, 224, 224], weight: [64, 64, 3, 3], Output Shape: [1, 64, 224, 224], flops: 1849688064.0
# 5 Conv Layer: Input Shape: [1, 64, 112, 112], weight: [128, 64, 3, 3], Output Shape: [1, 128, 112, 112], flops: 924844032.0
# 7 Conv Layer: Input Shape: [1, 128, 112, 112], weight: [128, 128, 3, 3], Output Shape: [1, 128, 112, 112], flops: 1849688064.0
# 10 Conv Layer: Input Shape: [1, 128, 56, 56], weight: [256, 128, 3, 3], Output Shape: [1, 256, 56, 56], flops: 924844032.0
# 12 Conv Layer: Input Shape: [1, 256, 56, 56], weight: [256, 256, 3, 3], Output Shape: [1, 256, 56, 56], flops: 1849688064.0
# 14 Conv Layer: Input Shape: [1, 256, 56, 56], weight: [256, 256, 3, 3], Output Shape: [1, 256, 56, 56], flops: 1849688064.0
# 16 Conv Layer: Input Shape: [1, 256, 56, 56], weight: [256, 256, 3, 3], Output Shape: [1, 256, 56, 56], flops: 1849688064.0
# 19 Conv Layer: Input Shape: [1, 256, 28, 28], weight: [512, 256, 3, 3], Output Shape: [1, 512, 28, 28], flops: 924844032.0
# 21 Conv Layer: Input Shape: [1, 512, 28, 28], weight: [512, 512, 3, 3], Output Shape: [1, 512, 28, 28], flops: 1849688064.0
# 23 Conv Layer: Input Shape: [1, 512, 28, 28], weight: [512, 512, 3, 3], Output Shape: [1, 512, 28, 28], flops: 1849688064.0
# 25 Conv Layer: Input Shape: [1, 512, 28, 28], weight: [512, 512, 3, 3], Output Shape: [1, 512, 28, 28], flops: 1849688064.0
# 28 Conv Layer: Input Shape: [1, 512, 14, 14], weight: [512, 512, 3, 3], Output Shape: [1, 512, 14, 14], flops: 462422016.0
# 30 Conv Layer: Input Shape: [1, 512, 14, 14], weight: [512, 512, 3, 3], Output Shape: [1, 512, 14, 14], flops: 462422016.0
# 32 Conv Layer: Input Shape: [1, 512, 14, 14], weight: [512, 512, 3, 3], Output Shape: [1, 512, 14, 14], flops: 462422016.0
# 34 Conv Layer: Input Shape: [1, 512, 14, 14], weight: [512, 512, 3, 3], Output Shape: [1, 512, 14, 14], flops: 462422016.0
# 38 Gemm flatten_72 Layer: Input Shape: [1, 25088], weight: [4096, 25088], Output Shape: [1, 4096], flops: 2578054119424
# 42 Gemm flatten_77 Layer: Input Shape: [1, 4096], weight: [4096, 4096], Output Shape: [1, 4096], flops: 68719476736
# 46 Gemm flatten_82 Layer: Input Shape: [1, 4096], weight: [1000, 4096], Output Shape: [1, 1000], flops: 16777216000
# model summary: /content/gdrive/MyDrive/ONNXAnalyser/onnx_models/vgg19-7.onnx
# Conv: 16
# Relu: 18
# MaxPool: 5
# Flatten: 3
# Gemm: 3
# Dropout: 2
# total operations: 47
# Model: inception-v1-12.onnx
#
# Layer Dimensions:
# 0 Conv Layer: Input Shape: [1, 3, 224, 224], weight: (64, 3, 7, 7), Output Shape: [1, 64, 112, 112], flops: 29503488.0
# 4 Conv Layer: Input Shape: [1, 64, 55, 55], weight: (64, 64, 1, 1), Output Shape: [1, 64, 55, 55], flops: 12390400.0
# 6 Conv Layer: Input Shape: [1, 64, 55, 55], weight: (192, 64, 3, 3), Output Shape: [1, 192, 55, 55], flops: 334540800.0
# 10 Conv Layer: Input Shape: [1, 192, 27, 27], weight: (64, 192, 1, 1), Output Shape: [1, 64, 27, 27], flops: 8957952.0
# 12 Conv Layer: Input Shape: [1, 192, 27, 27], weight: (96, 192, 1, 1), Output Shape: [1, 96, 27, 27], flops: 13436928.0
# 14 Conv Layer: Input Shape: [1, 96, 27, 27], weight: (128, 96, 3, 3), Output Shape: [1, 128, 27, 27], flops: 80621568.0
# 16 Conv Layer: Input Shape: [1, 192, 27, 27], weight: (16, 192, 1, 1), Output Shape: [1, 16, 27, 27], flops: 2239488.0
# 18 Conv Layer: Input Shape: [1, 16, 27, 27], weight: (32, 16, 5, 5), Output Shape: [1, 32, 27, 27], flops: 9331200.0
# 21 Conv Layer: Input Shape: [1, 192, 27, 27], weight: (32, 192, 1, 1), Output Shape: [1, 32, 27, 27], flops: 4478976.0
# 24 Conv Layer: Input Shape: [1, 256, 27, 27], weight: (128, 256, 1, 1), Output Shape: [1, 128, 27, 27], flops: 23887872.0
# 26 Conv Layer: Input Shape: [1, 256, 27, 27], weight: (128, 256, 1, 1), Output Shape: [1, 128, 27, 27], flops: 23887872.0
# 28 Conv Layer: Input Shape: [1, 128, 27, 27], weight: (192, 128, 3, 3), Output Shape: [1, 192, 27, 27], flops: 161243136.0
# 30 Conv Layer: Input Shape: [1, 256, 27, 27], weight: (32, 256, 1, 1), Output Shape: [1, 32, 27, 27], flops: 5971968.0
# 32 Conv Layer: Input Shape: [1, 32, 27, 27], weight: (96, 32, 5, 5), Output Shape: [1, 96, 27, 27], flops: 55987200.0
# 35 Conv Layer: Input Shape: [1, 256, 27, 27], weight: (64, 256, 1, 1), Output Shape: [1, 64, 27, 27], flops: 11943936.0
# 39 Conv Layer: Input Shape: [1, 480, 13, 13], weight: (192, 480, 1, 1), Output Shape: [1, 192, 13, 13], flops: 15575040.0
# 41 Conv Layer: Input Shape: [1, 480, 13, 13], weight: (96, 480, 1, 1), Output Shape: [1, 96, 13, 13], flops: 7787520.0
# 43 Conv Layer: Input Shape: [1, 96, 13, 13], weight: (208, 96, 3, 3), Output Shape: [1, 208, 13, 13], flops: 30371328.0
# 45 Conv Layer: Input Shape: [1, 480, 13, 13], weight: (16, 480, 1, 1), Output Shape: [1, 16, 13, 13], flops: 1297920.0
# 47 Conv Layer: Input Shape: [1, 16, 13, 13], weight: (48, 16, 5, 5), Output Shape: [1, 48, 13, 13], flops: 3244800.0
# 50 Conv Layer: Input Shape: [1, 480, 13, 13], weight: (64, 480, 1, 1), Output Shape: [1, 64, 13, 13], flops: 5191680.0
# 53 Conv Layer: Input Shape: [1, 512, 13, 13], weight: (160, 512, 1, 1), Output Shape: [1, 160, 13, 13], flops: 13844480.0
# 55 Conv Layer: Input Shape: [1, 512, 13, 13], weight: (112, 512, 1, 1), Output Shape: [1, 112, 13, 13], flops: 9691136.0
# 57 Conv Layer: Input Shape: [1, 112, 13, 13], weight: (224, 112, 3, 3), Output Shape: [1, 224, 13, 13], flops: 38158848.0
# 59 Conv Layer: Input Shape: [1, 512, 13, 13], weight: (24, 512, 1, 1), Output Shape: [1, 24, 13, 13], flops: 2076672.0
# 61 Conv Layer: Input Shape: [1, 24, 13, 13], weight: (64, 24, 5, 5), Output Shape: [1, 64, 13, 13], flops: 6489600.0
# 64 Conv Layer: Input Shape: [1, 512, 13, 13], weight: (64, 512, 1, 1), Output Shape: [1, 64, 13, 13], flops: 5537792.0
# 67 Conv Layer: Input Shape: [1, 512, 13, 13], weight: (128, 512, 1, 1), Output Shape: [1, 128, 13, 13], flops: 11075584.0
# 69 Conv Layer: Input Shape: [1, 512, 13, 13], weight: (128, 512, 1, 1), Output Shape: [1, 128, 13, 13], flops: 11075584.0
# 71 Conv Layer: Input Shape: [1, 128, 13, 13], weight: (256, 128, 3, 3), Output Shape: [1, 256, 13, 13], flops: 49840128.0
# 73 Conv Layer: Input Shape: [1, 512, 13, 13], weight: (24, 512, 1, 1), Output Shape: [1, 24, 13, 13], flops: 2076672.0
# 75 Conv Layer: Input Shape: [1, 24, 13, 13], weight: (64, 24, 5, 5), Output Shape: [1, 64, 13, 13], flops: 6489600.0
# 78 Conv Layer: Input Shape: [1, 512, 13, 13], weight: (64, 512, 1, 1), Output Shape: [1, 64, 13, 13], flops: 5537792.0
# 81 Conv Layer: Input Shape: [1, 512, 13, 13], weight: (112, 512, 1, 1), Output Shape: [1, 112, 13, 13], flops: 9691136.0
# 83 Conv Layer: Input Shape: [1, 512, 13, 13], weight: (144, 512, 1, 1), Output Shape: [1, 144, 13, 13], flops: 12460032.0
# 85 Conv Layer: Input Shape: [1, 144, 13, 13], weight: (288, 144, 3, 3), Output Shape: [1, 288, 13, 13], flops: 63078912.0
# 87 Conv Layer: Input Shape: [1, 512, 13, 13], weight: (32, 512, 1, 1), Output Shape: [1, 32, 13, 13], flops: 2768896.0
# 89 Conv Layer: Input Shape: [1, 32, 13, 13], weight: (64, 32, 5, 5), Output Shape: [1, 64, 13, 13], flops: 8652800.0
# 92 Conv Layer: Input Shape: [1, 512, 13, 13], weight: (64, 512, 1, 1), Output Shape: [1, 64, 13, 13], flops: 5537792.0
# 95 Conv Layer: Input Shape: [1, 528, 13, 13], weight: (256, 528, 1, 1), Output Shape: [1, 256, 13, 13], flops: 22843392.0
# 97 Conv Layer: Input Shape: [1, 528, 13, 13], weight: (160, 528, 1, 1), Output Shape: [1, 160, 13, 13], flops: 14277120.0
# 99 Conv Layer: Input Shape: [1, 160, 13, 13], weight: (320, 160, 3, 3), Output Shape: [1, 320, 13, 13], flops: 77875200.0
# 101 Conv Layer: Input Shape: [1, 528, 13, 13], weight: (32, 528, 1, 1), Output Shape: [1, 32, 13, 13], flops: 2855424.0
# 103 Conv Layer: Input Shape: [1, 32, 13, 13], weight: (128, 32, 5, 5), Output Shape: [1, 128, 13, 13], flops: 17305600.0
# 106 Conv Layer: Input Shape: [1, 528, 13, 13], weight: (128, 528, 1, 1), Output Shape: [1, 128, 13, 13], flops: 11421696.0
# 110 Conv Layer: Input Shape: [1, 832, 6, 6], weight: (256, 832, 1, 1), Output Shape: [1, 256, 6, 6], flops: 7667712.0
# 112 Conv Layer: Input Shape: [1, 832, 6, 6], weight: (160, 832, 1, 1), Output Shape: [1, 160, 6, 6], flops: 4792320.0
# 114 Conv Layer: Input Shape: [1, 160, 6, 6], weight: (320, 160, 3, 3), Output Shape: [1, 320, 6, 6], flops: 16588800.0
# 116 Conv Layer: Input Shape: [1, 832, 6, 6], weight: (32, 832, 1, 1), Output Shape: [1, 32, 6, 6], flops: 958464.0
# 118 Conv Layer: Input Shape: [1, 32, 6, 6], weight: (128, 32, 5, 5), Output Shape: [1, 128, 6, 6], flops: 3686400.0
# 121 Conv Layer: Input Shape: [1, 832, 6, 6], weight: (128, 832, 1, 1), Output Shape: [1, 128, 6, 6], flops: 3833856.0
# 124 Conv Layer: Input Shape: [1, 832, 6, 6], weight: (384, 832, 1, 1), Output Shape: [1, 384, 6, 6], flops: 11501568.0
# 126 Conv Layer: Input Shape: [1, 832, 6, 6], weight: (192, 832, 1, 1), Output Shape: [1, 192, 6, 6], flops: 5750784.0
# 128 Conv Layer: Input Shape: [1, 192, 6, 6], weight: (384, 192, 3, 3), Output Shape: [1, 384, 6, 6], flops: 23887872.0
# 130 Conv Layer: Input Shape: [1, 832, 6, 6], weight: (48, 832, 1, 1), Output Shape: [1, 48, 6, 6], flops: 1437696.0
# 132 Conv Layer: Input Shape: [1, 48, 6, 6], weight: (128, 48, 5, 5), Output Shape: [1, 128, 6, 6], flops: 5529600.0
# 135 Conv Layer: Input Shape: [1, 832, 6, 6], weight: (128, 832, 1, 1), Output Shape: [1, 128, 6, 6], flops: 3833856.0
# 138 AveragePool inception_5b/output_1 Layer: Input Shape: [1, 1024, 6, 6], Output Shape: [1, 1024, 1, 1], flops: 0
# 142 Gemm OC2_DUMMY_0 Layer: Input Shape: [1, 1024], weight: [1000, 1024], Output Shape: [1, 1000], flops: 1048576000
# model summary: /content/gdrive/MyDrive/ONNXAnalyser/onnx_models/inception-v1-12.onnx
# Conv: 57
# Relu: 57
# MaxPool: 13
# LRN: 2
# Concat: 9
# AveragePool: 1
# Dropout: 1
# Reshape: 2
# Gemm: 1
# Softmax: 1
# total operations: 144
# Model: inception-v2-9.onnx
#
# Layer Dimensions:
# 0 Conv Layer: Input Shape: [1, 3, 224, 224], weight: [64, 3, 7, 7], Output Shape: [1, 64, 112, 112], flops: 29503488.0
# 5 Add Layer: Input1 Shape: [1, 64, 112, 112], Input2 Shape: [64, 1, 1], Output Shape: [1, 64, 112, 112], flops: 150528
# 8 Conv Layer: Input Shape: [1, 64, 56, 56], weight: [64, 64, 1, 1], Output Shape: [1, 64, 56, 56], flops: 12845056.0
# 13 Add Layer: Input1 Shape: [1, 64, 56, 56], Input2 Shape: [64, 1, 1], Output Shape: [1, 64, 56, 56], flops: 200704
# 15 Conv Layer: Input Shape: [1, 64, 56, 56], weight: [192, 64, 3, 3], Output Shape: [1, 192, 56, 56], flops: 346816512.0
# 20 Add Layer: Input1 Shape: [1, 192, 56, 56], Input2 Shape: [192, 1, 1], Output Shape: [1, 192, 56, 56], flops: 200704
# 23 Conv Layer: Input Shape: [1, 192, 28, 28], weight: [64, 192, 1, 1], Output Shape: [1, 64, 28, 28], flops: 9633792.0
# 28 Add Layer: Input1 Shape: [1, 64, 28, 28], Input2 Shape: [64, 1, 1], Output Shape: [1, 64, 28, 28], flops: 150528
# 30 Conv Layer: Input Shape: [1, 192, 28, 28], weight: [64, 192, 1, 1], Output Shape: [1, 64, 28, 28], flops: 9633792.0
# 35 Add Layer: Input1 Shape: [1, 64, 28, 28], Input2 Shape: [64, 1, 1], Output Shape: [1, 64, 28, 28], flops: 150528
# 37 Conv Layer: Input Shape: [1, 64, 28, 28], weight: [64, 64, 3, 3], Output Shape: [1, 64, 28, 28], flops: 28901376.0
# 42 Add Layer: Input1 Shape: [1, 64, 28, 28], Input2 Shape: [64, 1, 1], Output Shape: [1, 64, 28, 28], flops: 50176
# 44 Conv Layer: Input Shape: [1, 192, 28, 28], weight: [64, 192, 1, 1], Output Shape: [1, 64, 28, 28], flops: 9633792.0
# 49 Add Layer: Input1 Shape: [1, 64, 28, 28], Input2 Shape: [64, 1, 1], Output Shape: [1, 64, 28, 28], flops: 150528
# 51 Conv Layer: Input Shape: [1, 64, 28, 28], weight: [96, 64, 3, 3], Output Shape: [1, 96, 28, 28], flops: 43352064.0
# 56 Add Layer: Input1 Shape: [1, 96, 28, 28], Input2 Shape: [96, 1, 1], Output Shape: [1, 96, 28, 28], flops: 50176
# 58 Conv Layer: Input Shape: [1, 96, 28, 28], weight: [96, 96, 3, 3], Output Shape: [1, 96, 28, 28], flops: 65028096.0
# 63 Add Layer: Input1 Shape: [1, 96, 28, 28], Input2 Shape: [96, 1, 1], Output Shape: [1, 96, 28, 28], flops: 75264
# 65 AveragePool pool2/3x3_s2_1 Layer: Input Shape: [1, 192, 28, 28], Output Shape: [1, 192, 28, 28], flops: 150528
# 66 Conv Layer: Input Shape: [1, 192, 28, 28], weight: [32, 192, 1, 1], Output Shape: [1, 32, 28, 28], flops: 4816896.0
# 71 Add Layer: Input1 Shape: [1, 32, 28, 28], Input2 Shape: [32, 1, 1], Output Shape: [1, 32, 28, 28], flops: 150528
# 74 Conv Layer: Input Shape: [1, 256, 28, 28], weight: [64, 256, 1, 1], Output Shape: [1, 64, 28, 28], flops: 12845056.0
# 79 Add Layer: Input1 Shape: [1, 64, 28, 28], Input2 Shape: [64, 1, 1], Output Shape: [1, 64, 28, 28], flops: 200704
# 81 Conv Layer: Input Shape: [1, 256, 28, 28], weight: [64, 256, 1, 1], Output Shape: [1, 64, 28, 28], flops: 12845056.0
# 86 Add Layer: Input1 Shape: [1, 64, 28, 28], Input2 Shape: [64, 1, 1], Output Shape: [1, 64, 28, 28], flops: 200704
# 88 Conv Layer: Input Shape: [1, 64, 28, 28], weight: [96, 64, 3, 3], Output Shape: [1, 96, 28, 28], flops: 43352064.0
# 93 Add Layer: Input1 Shape: [1, 96, 28, 28], Input2 Shape: [96, 1, 1], Output Shape: [1, 96, 28, 28], flops: 50176
# 95 Conv Layer: Input Shape: [1, 256, 28, 28], weight: [64, 256, 1, 1], Output Shape: [1, 64, 28, 28], flops: 12845056.0
# 100 Add Layer: Input1 Shape: [1, 64, 28, 28], Input2 Shape: [64, 1, 1], Output Shape: [1, 64, 28, 28], flops: 200704
# 102 Conv Layer: Input Shape: [1, 64, 28, 28], weight: [96, 64, 3, 3], Output Shape: [1, 96, 28, 28], flops: 43352064.0
# 107 Add Layer: Input1 Shape: [1, 96, 28, 28], Input2 Shape: [96, 1, 1], Output Shape: [1, 96, 28, 28], flops: 50176
# 109 Conv Layer: Input Shape: [1, 96, 28, 28], weight: [96, 96, 3, 3], Output Shape: [1, 96, 28, 28], flops: 65028096.0
# 114 Add Layer: Input1 Shape: [1, 96, 28, 28], Input2 Shape: [96, 1, 1], Output Shape: [1, 96, 28, 28], flops: 75264
# 116 AveragePool inception_3a/output_1 Layer: Input Shape: [1, 256, 28, 28], Output Shape: [1, 256, 28, 28], flops: 200704
# 117 Conv Layer: Input Shape: [1, 256, 28, 28], weight: [64, 256, 1, 1], Output Shape: [1, 64, 28, 28], flops: 12845056.0
# 122 Add Layer: Input1 Shape: [1, 64, 28, 28], Input2 Shape: [64, 1, 1], Output Shape: [1, 64, 28, 28], flops: 200704
# 125 Conv Layer: Input Shape: [1, 320, 28, 28], weight: [128, 320, 1, 1], Output Shape: [1, 128, 28, 28], flops: 32112640.0
# 130 Add Layer: Input1 Shape: [1, 128, 28, 28], Input2 Shape: [128, 1, 1], Output Shape: [1, 128, 28, 28], flops: 250880
# 132 Conv Layer: Input Shape: [1, 128, 28, 28], weight: [160, 128, 3, 3], Output Shape: [1, 160, 14, 14], flops: 9031680.0
# 137 Add Layer: Input1 Shape: [1, 160, 14, 14], Input2 Shape: [160, 1, 1], Output Shape: [1, 160, 14, 14], flops: 100352
# 139 Conv Layer: Input Shape: [1, 320, 28, 28], weight: [64, 320, 1, 1], Output Shape: [1, 64, 28, 28], flops: 16056320.0
# 144 Add Layer: Input1 Shape: [1, 64, 28, 28], Input2 Shape: [64, 1, 1], Output Shape: [1, 64, 28, 28], flops: 250880
# 146 Conv Layer: Input Shape: [1, 64, 28, 28], weight: [96, 64, 3, 3], Output Shape: [1, 96, 28, 28], flops: 43352064.0
# 151 Add Layer: Input1 Shape: [1, 96, 28, 28], Input2 Shape: [96, 1, 1], Output Shape: [1, 96, 28, 28], flops: 50176
# 153 Conv Layer: Input Shape: [1, 96, 28, 28], weight: [96, 96, 3, 3], Output Shape: [1, 96, 14, 14], flops: 4064256.0
# 158 Add Layer: Input1 Shape: [1, 96, 14, 14], Input2 Shape: [96, 1, 1], Output Shape: [1, 96, 14, 14], flops: 75264
# 162 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [224, 576, 1, 1], Output Shape: [1, 224, 14, 14], flops: 25288704.0
# 167 Add Layer: Input1 Shape: [1, 224, 14, 14], Input2 Shape: [224, 1, 1], Output Shape: [1, 224, 14, 14], flops: 112896
# 169 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [64, 576, 1, 1], Output Shape: [1, 64, 14, 14], flops: 7225344.0
# 174 Add Layer: Input1 Shape: [1, 64, 14, 14], Input2 Shape: [64, 1, 1], Output Shape: [1, 64, 14, 14], flops: 112896
# 176 Conv Layer: Input Shape: [1, 64, 14, 14], weight: [96, 64, 3, 3], Output Shape: [1, 96, 14, 14], flops: 10838016.0
# 181 Add Layer: Input1 Shape: [1, 96, 14, 14], Input2 Shape: [96, 1, 1], Output Shape: [1, 96, 14, 14], flops: 12544
# 183 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [96, 576, 1, 1], Output Shape: [1, 96, 14, 14], flops: 10838016.0
# 188 Add Layer: Input1 Shape: [1, 96, 14, 14], Input2 Shape: [96, 1, 1], Output Shape: [1, 96, 14, 14], flops: 112896
# 190 Conv Layer: Input Shape: [1, 96, 14, 14], weight: [128, 96, 3, 3], Output Shape: [1, 128, 14, 14], flops: 21676032.0
# 195 Add Layer: Input1 Shape: [1, 128, 14, 14], Input2 Shape: [128, 1, 1], Output Shape: [1, 128, 14, 14], flops: 18816
# 197 Conv Layer: Input Shape: [1, 128, 14, 14], weight: [128, 128, 3, 3], Output Shape: [1, 128, 14, 14], flops: 28901376.0
# 202 Add Layer: Input1 Shape: [1, 128, 14, 14], Input2 Shape: [128, 1, 1], Output Shape: [1, 128, 14, 14], flops: 25088
# 204 AveragePool inception_3c/output_1 Layer: Input Shape: [1, 576, 14, 14], Output Shape: [1, 576, 14, 14], flops: 112896
# 205 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [128, 576, 1, 1], Output Shape: [1, 128, 14, 14], flops: 14450688.0
# 210 Add Layer: Input1 Shape: [1, 128, 14, 14], Input2 Shape: [128, 1, 1], Output Shape: [1, 128, 14, 14], flops: 112896
# 213 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [192, 576, 1, 1], Output Shape: [1, 192, 14, 14], flops: 21676032.0
# 218 Add Layer: Input1 Shape: [1, 192, 14, 14], Input2 Shape: [192, 1, 1], Output Shape: [1, 192, 14, 14], flops: 112896
# 220 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [96, 576, 1, 1], Output Shape: [1, 96, 14, 14], flops: 10838016.0
# 225 Add Layer: Input1 Shape: [1, 96, 14, 14], Input2 Shape: [96, 1, 1], Output Shape: [1, 96, 14, 14], flops: 112896
# 227 Conv Layer: Input Shape: [1, 96, 14, 14], weight: [128, 96, 3, 3], Output Shape: [1, 128, 14, 14], flops: 21676032.0
# 232 Add Layer: Input1 Shape: [1, 128, 14, 14], Input2 Shape: [128, 1, 1], Output Shape: [1, 128, 14, 14], flops: 18816
# 234 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [96, 576, 1, 1], Output Shape: [1, 96, 14, 14], flops: 10838016.0
# 239 Add Layer: Input1 Shape: [1, 96, 14, 14], Input2 Shape: [96, 1, 1], Output Shape: [1, 96, 14, 14], flops: 112896
# 241 Conv Layer: Input Shape: [1, 96, 14, 14], weight: [128, 96, 3, 3], Output Shape: [1, 128, 14, 14], flops: 21676032.0
# 246 Add Layer: Input1 Shape: [1, 128, 14, 14], Input2 Shape: [128, 1, 1], Output Shape: [1, 128, 14, 14], flops: 18816
# 248 Conv Layer: Input Shape: [1, 128, 14, 14], weight: [128, 128, 3, 3], Output Shape: [1, 128, 14, 14], flops: 28901376.0
# 253 Add Layer: Input1 Shape: [1, 128, 14, 14], Input2 Shape: [128, 1, 1], Output Shape: [1, 128, 14, 14], flops: 25088
# 255 AveragePool inception_4a/output_1 Layer: Input Shape: [1, 576, 14, 14], Output Shape: [1, 576, 14, 14], flops: 112896
# 256 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [128, 576, 1, 1], Output Shape: [1, 128, 14, 14], flops: 14450688.0
# 261 Add Layer: Input1 Shape: [1, 128, 14, 14], Input2 Shape: [128, 1, 1], Output Shape: [1, 128, 14, 14], flops: 112896
# 264 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [160, 576, 1, 1], Output Shape: [1, 160, 14, 14], flops: 18063360.0
# 269 Add Layer: Input1 Shape: [1, 160, 14, 14], Input2 Shape: [160, 1, 1], Output Shape: [1, 160, 14, 14], flops: 112896
# 271 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [128, 576, 1, 1], Output Shape: [1, 128, 14, 14], flops: 14450688.0
# 276 Add Layer: Input1 Shape: [1, 128, 14, 14], Input2 Shape: [128, 1, 1], Output Shape: [1, 128, 14, 14], flops: 112896
# 278 Conv Layer: Input Shape: [1, 128, 14, 14], weight: [160, 128, 3, 3], Output Shape: [1, 160, 14, 14], flops: 36126720.0
# 283 Add Layer: Input1 Shape: [1, 160, 14, 14], Input2 Shape: [160, 1, 1], Output Shape: [1, 160, 14, 14], flops: 25088
# 285 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [128, 576, 1, 1], Output Shape: [1, 128, 14, 14], flops: 14450688.0
# 290 Add Layer: Input1 Shape: [1, 128, 14, 14], Input2 Shape: [128, 1, 1], Output Shape: [1, 128, 14, 14], flops: 112896
# 292 Conv Layer: Input Shape: [1, 128, 14, 14], weight: [160, 128, 3, 3], Output Shape: [1, 160, 14, 14], flops: 36126720.0
# 297 Add Layer: Input1 Shape: [1, 160, 14, 14], Input2 Shape: [160, 1, 1], Output Shape: [1, 160, 14, 14], flops: 25088
# 299 Conv Layer: Input Shape: [1, 160, 14, 14], weight: [160, 160, 3, 3], Output Shape: [1, 160, 14, 14], flops: 45158400.0
# 304 Add Layer: Input1 Shape: [1, 160, 14, 14], Input2 Shape: [160, 1, 1], Output Shape: [1, 160, 14, 14], flops: 31360
# 306 AveragePool inception_4b/output_1 Layer: Input Shape: [1, 576, 14, 14], Output Shape: [1, 576, 14, 14], flops: 112896
# 307 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [96, 576, 1, 1], Output Shape: [1, 96, 14, 14], flops: 10838016.0
# 312 Add Layer: Input1 Shape: [1, 96, 14, 14], Input2 Shape: [96, 1, 1], Output Shape: [1, 96, 14, 14], flops: 112896
# 315 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [96, 576, 1, 1], Output Shape: [1, 96, 14, 14], flops: 10838016.0
# 320 Add Layer: Input1 Shape: [1, 96, 14, 14], Input2 Shape: [96, 1, 1], Output Shape: [1, 96, 14, 14], flops: 112896
# 322 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [128, 576, 1, 1], Output Shape: [1, 128, 14, 14], flops: 14450688.0
# 327 Add Layer: Input1 Shape: [1, 128, 14, 14], Input2 Shape: [128, 1, 1], Output Shape: [1, 128, 14, 14], flops: 112896
# 329 Conv Layer: Input Shape: [1, 128, 14, 14], weight: [192, 128, 3, 3], Output Shape: [1, 192, 14, 14], flops: 43352064.0
# 334 Add Layer: Input1 Shape: [1, 192, 14, 14], Input2 Shape: [192, 1, 1], Output Shape: [1, 192, 14, 14], flops: 25088
# 336 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [160, 576, 1, 1], Output Shape: [1, 160, 14, 14], flops: 18063360.0
# 341 Add Layer: Input1 Shape: [1, 160, 14, 14], Input2 Shape: [160, 1, 1], Output Shape: [1, 160, 14, 14], flops: 112896
# 343 Conv Layer: Input Shape: [1, 160, 14, 14], weight: [192, 160, 3, 3], Output Shape: [1, 192, 14, 14], flops: 54190080.0
# 348 Add Layer: Input1 Shape: [1, 192, 14, 14], Input2 Shape: [192, 1, 1], Output Shape: [1, 192, 14, 14], flops: 31360
# 350 Conv Layer: Input Shape: [1, 192, 14, 14], weight: [192, 192, 3, 3], Output Shape: [1, 192, 14, 14], flops: 65028096.0
# 355 Add Layer: Input1 Shape: [1, 192, 14, 14], Input2 Shape: [192, 1, 1], Output Shape: [1, 192, 14, 14], flops: 37632
# 357 AveragePool inception_4c/output_1 Layer: Input Shape: [1, 576, 14, 14], Output Shape: [1, 576, 14, 14], flops: 112896
# 358 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [96, 576, 1, 1], Output Shape: [1, 96, 14, 14], flops: 10838016.0
# 363 Add Layer: Input1 Shape: [1, 96, 14, 14], Input2 Shape: [96, 1, 1], Output Shape: [1, 96, 14, 14], flops: 112896
# 366 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [128, 576, 1, 1], Output Shape: [1, 128, 14, 14], flops: 14450688.0
# 371 Add Layer: Input1 Shape: [1, 128, 14, 14], Input2 Shape: [128, 1, 1], Output Shape: [1, 128, 14, 14], flops: 112896
# 373 Conv Layer: Input Shape: [1, 128, 14, 14], weight: [192, 128, 3, 3], Output Shape: [1, 192, 7, 7], flops: 2709504.0
# 378 Add Layer: Input1 Shape: [1, 192, 7, 7], Input2 Shape: [192, 1, 1], Output Shape: [1, 192, 7, 7], flops: 25088
# 380 Conv Layer: Input Shape: [1, 576, 14, 14], weight: [192, 576, 1, 1], Output Shape: [1, 192, 14, 14], flops: 21676032.0
# 385 Add Layer: Input1 Shape: [1, 192, 14, 14], Input2 Shape: [192, 1, 1], Output Shape: [1, 192, 14, 14], flops: 112896
# 387 Conv Layer: Input Shape: [1, 192, 14, 14], weight: [256, 192, 3, 3], Output Shape: [1, 256, 14, 14], flops: 86704128.0
# 392 Add Layer: Input1 Shape: [1, 256, 14, 14], Input2 Shape: [256, 1, 1], Output Shape: [1, 256, 14, 14], flops: 37632
# 394 Conv Layer: Input Shape: [1, 256, 14, 14], weight: [256, 256, 3, 3], Output Shape: [1, 256, 7, 7], flops: 7225344.0
# 399 Add Layer: Input1 Shape: [1, 256, 7, 7], Input2 Shape: [256, 1, 1], Output Shape: [1, 256, 7, 7], flops: 50176
# 403 Conv Layer: Input Shape: [1, 1024, 7, 7], weight: [352, 1024, 1, 1], Output Shape: [1, 352, 7, 7], flops: 17661952.0
# 408 Add Layer: Input1 Shape: [1, 352, 7, 7], Input2 Shape: [352, 1, 1], Output Shape: [1, 352, 7, 7], flops: 50176
# 410 Conv Layer: Input Shape: [1, 1024, 7, 7], weight: [192, 1024, 1, 1], Output Shape: [1, 192, 7, 7], flops: 9633792.0
# 415 Add Layer: Input1 Shape: [1, 192, 7, 7], Input2 Shape: [192, 1, 1], Output Shape: [1, 192, 7, 7], flops: 50176
# 417 Conv Layer: Input Shape: [1, 192, 7, 7], weight: [320, 192, 3, 3], Output Shape: [1, 320, 7, 7], flops: 27095040.0
# 422 Add Layer: Input1 Shape: [1, 320, 7, 7], Input2 Shape: [320, 1, 1], Output Shape: [1, 320, 7, 7], flops: 9408
# 424 Conv Layer: Input Shape: [1, 1024, 7, 7], weight: [160, 1024, 1, 1], Output Shape: [1, 160, 7, 7], flops: 8028160.0
# 429 Add Layer: Input1 Shape: [1, 160, 7, 7], Input2 Shape: [160, 1, 1], Output Shape: [1, 160, 7, 7], flops: 50176
# 431 Conv Layer: Input Shape: [1, 160, 7, 7], weight: [224, 160, 3, 3], Output Shape: [1, 224, 7, 7], flops: 15805440.0
# 436 Add Layer: Input1 Shape: [1, 224, 7, 7], Input2 Shape: [224, 1, 1], Output Shape: [1, 224, 7, 7], flops: 7840
# 438 Conv Layer: Input Shape: [1, 224, 7, 7], weight: [224, 224, 3, 3], Output Shape: [1, 224, 7, 7], flops: 22127616.0
# 443 Add Layer: Input1 Shape: [1, 224, 7, 7], Input2 Shape: [224, 1, 1], Output Shape: [1, 224, 7, 7], flops: 10976
# 445 AveragePool inception_4e/output_1 Layer: Input Shape: [1, 1024, 7, 7], Output Shape: [1, 1024, 7, 7], flops: 50176
# 446 Conv Layer: Input Shape: [1, 1024, 7, 7], weight: [128, 1024, 1, 1], Output Shape: [1, 128, 7, 7], flops: 6422528.0
# 451 Add Layer: Input1 Shape: [1, 128, 7, 7], Input2 Shape: [128, 1, 1], Output Shape: [1, 128, 7, 7], flops: 50176
# 454 Conv Layer: Input Shape: [1, 1024, 7, 7], weight: [352, 1024, 1, 1], Output Shape: [1, 352, 7, 7], flops: 17661952.0
# 459 Add Layer: Input1 Shape: [1, 352, 7, 7], Input2 Shape: [352, 1, 1], Output Shape: [1, 352, 7, 7], flops: 50176
# 461 Conv Layer: Input Shape: [1, 1024, 7, 7], weight: [192, 1024, 1, 1], Output Shape: [1, 192, 7, 7], flops: 9633792.0
# 466 Add Layer: Input1 Shape: [1, 192, 7, 7], Input2 Shape: [192, 1, 1], Output Shape: [1, 192, 7, 7], flops: 50176
# 468 Conv Layer: Input Shape: [1, 192, 7, 7], weight: [320, 192, 3, 3], Output Shape: [1, 320, 7, 7], flops: 27095040.0
# 473 Add Layer: Input1 Shape: [1, 320, 7, 7], Input2 Shape: [320, 1, 1], Output Shape: [1, 320, 7, 7], flops: 9408
# 475 Conv Layer: Input Shape: [1, 1024, 7, 7], weight: [192, 1024, 1, 1], Output Shape: [1, 192, 7, 7], flops: 9633792.0
# 480 Add Layer: Input1 Shape: [1, 192, 7, 7], Input2 Shape: [192, 1, 1], Output Shape: [1, 192, 7, 7], flops: 50176
# 482 Conv Layer: Input Shape: [1, 192, 7, 7], weight: [224, 192, 3, 3], Output Shape: [1, 224, 7, 7], flops: 18966528.0
# 487 Add Layer: Input1 Shape: [1, 224, 7, 7], Input2 Shape: [224, 1, 1], Output Shape: [1, 224, 7, 7], flops: 9408
# 489 Conv Layer: Input Shape: [1, 224, 7, 7], weight: [224, 224, 3, 3], Output Shape: [1, 224, 7, 7], flops: 22127616.0
# 494 Add Layer: Input1 Shape: [1, 224, 7, 7], Input2 Shape: [224, 1, 1], Output Shape: [1, 224, 7, 7], flops: 10976
# 497 Conv Layer: Input Shape: [1, 1024, 7, 7], weight: [128, 1024, 1, 1], Output Shape: [1, 128, 7, 7], flops: 6422528.0
# 502 Add Layer: Input1 Shape: [1, 128, 7, 7], Input2 Shape: [128, 1, 1], Output Shape: [1, 128, 7, 7], flops: 50176
# 505 AveragePool inception_5b/output_1 Layer: Input Shape: [1, 1024, 7, 7], Output Shape: [1, 1024, 1, 1], flops: 0
# 507 Gemm OC2_DUMMY_138 Layer: Input Shape: [1, 1024], weight: [1000, 1024], Output Shape: [1, 1000], flops: 1048576000
# model summary: /content/gdrive/MyDrive/ONNXAnalyser/onnx_models/inception-v2-9.onnx
# Conv: 69
# BatchNormalization: 69
# Unsqueeze: 138
# Mul: 69
# Add: 69
# Relu: 69
# MaxPool: 5
# AveragePool: 8
# Concat: 10
# Reshape: 1
# Gemm: 1
# Softmax: 1
# total operations: 509
# Model: googlenet-12.onnx
#
# Layer Dimensions:
# 0 Conv Layer: Input Shape: [1, 3, 224, 224], weight: (64, 3, 7, 7), Output Shape: [1, 64, 112, 112], flops: 29503488.0
# 4 Conv Layer: Input Shape: [1, 64, 56, 56], weight: (64, 64, 1, 1), Output Shape: [1, 64, 56, 56], flops: 12845056.0
# 6 Conv Layer: Input Shape: [1, 64, 56, 56], weight: (192, 64, 3, 3), Output Shape: [1, 192, 56, 56], flops: 346816512.0
# 10 Conv Layer: Input Shape: [1, 192, 28, 28], weight: (64, 192, 1, 1), Output Shape: [1, 64, 28, 28], flops: 9633792.0
# 12 Conv Layer: Input Shape: [1, 192, 28, 28], weight: (96, 192, 1, 1), Output Shape: [1, 96, 28, 28], flops: 14450688.0
# 14 Conv Layer: Input Shape: [1, 96, 28, 28], weight: (128, 96, 3, 3), Output Shape: [1, 128, 28, 28], flops: 86704128.0
# 16 Conv Layer: Input Shape: [1, 192, 28, 28], weight: (16, 192, 1, 1), Output Shape: [1, 16, 28, 28], flops: 2408448.0
# 18 Conv Layer: Input Shape: [1, 16, 28, 28], weight: (32, 16, 5, 5), Output Shape: [1, 32, 28, 28], flops: 10035200.0
# 21 Conv Layer: Input Shape: [1, 192, 28, 28], weight: (32, 192, 1, 1), Output Shape: [1, 32, 28, 28], flops: 4816896.0
# 24 Conv Layer: Input Shape: [1, 256, 28, 28], weight: (128, 256, 1, 1), Output Shape: [1, 128, 28, 28], flops: 25690112.0
# 26 Conv Layer: Input Shape: [1, 256, 28, 28], weight: (128, 256, 1, 1), Output Shape: [1, 128, 28, 28], flops: 25690112.0
# 28 Conv Layer: Input Shape: [1, 128, 28, 28], weight: (192, 128, 3, 3), Output Shape: [1, 192, 28, 28], flops: 173408256.0
# 30 Conv Layer: Input Shape: [1, 256, 28, 28], weight: (32, 256, 1, 1), Output Shape: [1, 32, 28, 28], flops: 6422528.0
# 32 Conv Layer: Input Shape: [1, 32, 28, 28], weight: (96, 32, 5, 5), Output Shape: [1, 96, 28, 28], flops: 60211200.0
# 35 Conv Layer: Input Shape: [1, 256, 28, 28], weight: (64, 256, 1, 1), Output Shape: [1, 64, 28, 28], flops: 12845056.0
# 39 Conv Layer: Input Shape: [1, 480, 14, 14], weight: (192, 480, 1, 1), Output Shape: [1, 192, 14, 14], flops: 18063360.0
# 41 Conv Layer: Input Shape: [1, 480, 14, 14], weight: (96, 480, 1, 1), Output Shape: [1, 96, 14, 14], flops: 9031680.0
# 43 Conv Layer: Input Shape: [1, 96, 14, 14], weight: (208, 96, 3, 3), Output Shape: [1, 208, 14, 14], flops: 35223552.0
# 45 Conv Layer: Input Shape: [1, 480, 14, 14], weight: (16, 480, 1, 1), Output Shape: [1, 16, 14, 14], flops: 1505280.0
# 47 Conv Layer: Input Shape: [1, 16, 14, 14], weight: (48, 16, 5, 5), Output Shape: [1, 48, 14, 14], flops: 3763200.0
# 50 Conv Layer: Input Shape: [1, 480, 14, 14], weight: (64, 480, 1, 1), Output Shape: [1, 64, 14, 14], flops: 6021120.0
# 53 Conv Layer: Input Shape: [1, 512, 14, 14], weight: (160, 512, 1, 1), Output Shape: [1, 160, 14, 14], flops: 16056320.0
# 55 Conv Layer: Input Shape: [1, 512, 14, 14], weight: (112, 512, 1, 1), Output Shape: [1, 112, 14, 14], flops: 11239424.0
# 57 Conv Layer: Input Shape: [1, 112, 14, 14], weight: (224, 112, 3, 3), Output Shape: [1, 224, 14, 14], flops: 44255232.0
# 59 Conv Layer: Input Shape: [1, 512, 14, 14], weight: (24, 512, 1, 1), Output Shape: [1, 24, 14, 14], flops: 2408448.0
# 61 Conv Layer: Input Shape: [1, 24, 14, 14], weight: (64, 24, 5, 5), Output Shape: [1, 64, 14, 14], flops: 7526400.0
# 64 Conv Layer: Input Shape: [1, 512, 14, 14], weight: (64, 512, 1, 1), Output Shape: [1, 64, 14, 14], flops: 6422528.0
# 67 Conv Layer: Input Shape: [1, 512, 14, 14], weight: (128, 512, 1, 1), Output Shape: [1, 128, 14, 14], flops: 12845056.0
# 69 Conv Layer: Input Shape: [1, 512, 14, 14], weight: (128, 512, 1, 1), Output Shape: [1, 128, 14, 14], flops: 12845056.0
# 71 Conv Layer: Input Shape: [1, 128, 14, 14], weight: (256, 128, 3, 3), Output Shape: [1, 256, 14, 14], flops: 57802752.0
# 73 Conv Layer: Input Shape: [1, 512, 14, 14], weight: (24, 512, 1, 1), Output Shape: [1, 24, 14, 14], flops: 2408448.0
# 75 Conv Layer: Input Shape: [1, 24, 14, 14], weight: (64, 24, 5, 5), Output Shape: [1, 64, 14, 14], flops: 7526400.0
# 78 Conv Layer: Input Shape: [1, 512, 14, 14], weight: (64, 512, 1, 1), Output Shape: [1, 64, 14, 14], flops: 6422528.0
# 81 Conv Layer: Input Shape: [1, 512, 14, 14], weight: (112, 512, 1, 1), Output Shape: [1, 112, 14, 14], flops: 11239424.0
# 83 Conv Layer: Input Shape: [1, 512, 14, 14], weight: (144, 512, 1, 1), Output Shape: [1, 144, 14, 14], flops: 14450688.0
# 85 Conv Layer: Input Shape: [1, 144, 14, 14], weight: (288, 144, 3, 3), Output Shape: [1, 288, 14, 14], flops: 73156608.0
# 87 Conv Layer: Input Shape: [1, 512, 14, 14], weight: (32, 512, 1, 1), Output Shape: [1, 32, 14, 14], flops: 3211264.0
# 89 Conv Layer: Input Shape: [1, 32, 14, 14], weight: (64, 32, 5, 5), Output Shape: [1, 64, 14, 14], flops: 10035200.0
# 92 Conv Layer: Input Shape: [1, 512, 14, 14], weight: (64, 512, 1, 1), Output Shape: [1, 64, 14, 14], flops: 6422528.0
# 95 Conv Layer: Input Shape: [1, 528, 14, 14], weight: (256, 528, 1, 1), Output Shape: [1, 256, 14, 14], flops: 26492928.0
# 97 Conv Layer: Input Shape: [1, 528, 14, 14], weight: (160, 528, 1, 1), Output Shape: [1, 160, 14, 14], flops: 16558080.0
# 99 Conv Layer: Input Shape: [1, 160, 14, 14], weight: (320, 160, 3, 3), Output Shape: [1, 320, 14, 14], flops: 90316800.0
# 101 Conv Layer: Input Shape: [1, 528, 14, 14], weight: (32, 528, 1, 1), Output Shape: [1, 32, 14, 14], flops: 3311616.0
# 103 Conv Layer: Input Shape: [1, 32, 14, 14], weight: (128, 32, 5, 5), Output Shape: [1, 128, 14, 14], flops: 20070400.0
# 106 Conv Layer: Input Shape: [1, 528, 14, 14], weight: (128, 528, 1, 1), Output Shape: [1, 128, 14, 14], flops: 13246464.0
# 110 Conv Layer: Input Shape: [1, 832, 7, 7], weight: (256, 832, 1, 1), Output Shape: [1, 256, 7, 7], flops: 10436608.0
# 112 Conv Layer: Input Shape: [1, 832, 7, 7], weight: (160, 832, 1, 1), Output Shape: [1, 160, 7, 7], flops: 6522880.0
# 114 Conv Layer: Input Shape: [1, 160, 7, 7], weight: (320, 160, 3, 3), Output Shape: [1, 320, 7, 7], flops: 22579200.0
# 116 Conv Layer: Input Shape: [1, 832, 7, 7], weight: (32, 832, 1, 1), Output Shape: [1, 32, 7, 7], flops: 1304576.0
# 118 Conv Layer: Input Shape: [1, 32, 7, 7], weight: (128, 32, 5, 5), Output Shape: [1, 128, 7, 7], flops: 5017600.0
# 121 Conv Layer: Input Shape: [1, 832, 7, 7], weight: (128, 832, 1, 1), Output Shape: [1, 128, 7, 7], flops: 5218304.0
# 124 Conv Layer: Input Shape: [1, 832, 7, 7], weight: (384, 832, 1, 1), Output Shape: [1, 384, 7, 7], flops: 15654912.0
# 126 Conv Layer: Input Shape: [1, 832, 7, 7], weight: (192, 832, 1, 1), Output Shape: [1, 192, 7, 7], flops: 7827456.0
# 128 Conv Layer: Input Shape: [1, 192, 7, 7], weight: (384, 192, 3, 3), Output Shape: [1, 384, 7, 7], flops: 32514048.0
# 130 Conv Layer: Input Shape: [1, 832, 7, 7], weight: (48, 832, 1, 1), Output Shape: [1, 48, 7, 7], flops: 1956864.0
# 132 Conv Layer: Input Shape: [1, 48, 7, 7], weight: (128, 48, 5, 5), Output Shape: [1, 128, 7, 7], flops: 7526400.0
# 135 Conv Layer: Input Shape: [1, 832, 7, 7], weight: (128, 832, 1, 1), Output Shape: [1, 128, 7, 7], flops: 5218304.0
# 138 AveragePool inception_5b/output_1 Layer: Input Shape: [1, 1024, 7, 7], Output Shape: [1, 1024, 1, 1], flops: 0
# 141 Gemm OC2_DUMMY_0 Layer: Input Shape: [1, 1024], weight: (1000, 1024), Output Shape: [1, 1000], flops: 1048576000
# model summary: /content/gdrive/MyDrive/ONNXAnalyser/onnx_models/googlenet-12.onnx
# Conv: 57
# Relu: 57
# MaxPool: 13
# LRN: 2
# Concat: 9
# AveragePool: 1
# Dropout: 1
# Reshape: 1
# Gemm: 1
# Softmax: 1
# total operations: 143
# Model: resnet18-v1-7.onnx
#
# Layer Dimensions:
# 0 Conv Layer: Input Shape: [0, 3, 224, 224], weight: [64, 3, 7, 7], Output Shape: [0, 64, 112, 112], flops: 29503488.0
# 4 Conv Layer: Input Shape: [0, 64, 56, 56], weight: [64, 64, 3, 3], Output Shape: [0, 64, 56, 56], flops: 115605504.0
# 7 Conv Layer: Input Shape: [0, 64, 56, 56], weight: [64, 64, 3, 3], Output Shape: [0, 64, 56, 56], flops: 115605504.0
# 9 Add Layer: Input1 Shape: [0, 64, 56, 56], Input2 Shape: [0, 64, 56, 56], Output Shape: [0, 64, 56, 56], flops: 200704
# 11 Conv Layer: Input Shape: [0, 64, 56, 56], weight: [64, 64, 3, 3], Output Shape: [0, 64, 56, 56], flops: 115605504.0
# 14 Conv Layer: Input Shape: [0, 64, 56, 56], weight: [64, 64, 3, 3], Output Shape: [0, 64, 56, 56], flops: 115605504.0
# 16 Add Layer: Input1 Shape: [0, 64, 56, 56], Input2 Shape: [0, 64, 56, 56], Output Shape: [0, 64, 56, 56], flops: 200704
# 18 Conv Layer: Input Shape: [0, 64, 56, 56], weight: [128, 64, 1, 1], Output Shape: [0, 128, 28, 28], flops: 1605632.0
# 20 Conv Layer: Input Shape: [0, 64, 56, 56], weight: [128, 64, 3, 3], Output Shape: [0, 128, 28, 28], flops: 14450688.0
# 23 Conv Layer: Input Shape: [0, 128, 28, 28], weight: [128, 128, 3, 3], Output Shape: [0, 128, 28, 28], flops: 115605504.0
# 25 Add Layer: Input1 Shape: [0, 128, 28, 28], Input2 Shape: [0, 128, 28, 28], Output Shape: [0, 128, 28, 28], flops: 100352
# 27 Conv Layer: Input Shape: [0, 128, 28, 28], weight: [128, 128, 3, 3], Output Shape: [0, 128, 28, 28], flops: 115605504.0
# 30 Conv Layer: Input Shape: [0, 128, 28, 28], weight: [128, 128, 3, 3], Output Shape: [0, 128, 28, 28], flops: 115605504.0
# 32 Add Layer: Input1 Shape: [0, 128, 28, 28], Input2 Shape: [0, 128, 28, 28], Output Shape: [0, 128, 28, 28], flops: 100352
# 34 Conv Layer: Input Shape: [0, 128, 28, 28], weight: [256, 128, 1, 1], Output Shape: [0, 256, 14, 14], flops: 1605632.0
# 36 Conv Layer: Input Shape: [0, 128, 28, 28], weight: [256, 128, 3, 3], Output Shape: [0, 256, 14, 14], flops: 14450688.0
# 39 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [256, 256, 3, 3], Output Shape: [0, 256, 14, 14], flops: 115605504.0
# 41 Add Layer: Input1 Shape: [0, 256, 14, 14], Input2 Shape: [0, 256, 14, 14], Output Shape: [0, 256, 14, 14], flops: 50176
# 43 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [256, 256, 3, 3], Output Shape: [0, 256, 14, 14], flops: 115605504.0
# 46 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [256, 256, 3, 3], Output Shape: [0, 256, 14, 14], flops: 115605504.0
# 48 Add Layer: Input1 Shape: [0, 256, 14, 14], Input2 Shape: [0, 256, 14, 14], Output Shape: [0, 256, 14, 14], flops: 50176
# 50 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [512, 256, 1, 1], Output Shape: [0, 512, 7, 7], flops: 1605632.0
# 52 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [512, 256, 3, 3], Output Shape: [0, 512, 7, 7], flops: 14450688.0
# 55 Conv Layer: Input Shape: [0, 512, 7, 7], weight: [512, 512, 3, 3], Output Shape: [0, 512, 7, 7], flops: 115605504.0
# 57 Add Layer: Input1 Shape: [0, 512, 7, 7], Input2 Shape: [0, 512, 7, 7], Output Shape: [0, 512, 7, 7], flops: 25088
# 59 Conv Layer: Input Shape: [0, 512, 7, 7], weight: [512, 512, 3, 3], Output Shape: [0, 512, 7, 7], flops: 115605504.0
# 62 Conv Layer: Input Shape: [0, 512, 7, 7], weight: [512, 512, 3, 3], Output Shape: [0, 512, 7, 7], flops: 115605504.0
# 64 Add Layer: Input1 Shape: [0, 512, 7, 7], Input2 Shape: [0, 512, 7, 7], Output Shape: [0, 512, 7, 7], flops: 25088
# 66 GlobalAveragePool resnetv15_stage4_activation1 Layer: Input Shape: [0, 512, 7, 7], Output Shape: [0, 512, 1, 1], flops: 25088
# 68 Gemm flatten_170 Layer: Input Shape: [0, 512], weight: [1000, 512], Output Shape: [0, 1000], flops: 262144000
# model summary: /content/gdrive/MyDrive/ONNXAnalyser/onnx_models/resnet18-v1-7.onnx
# Conv: 20
# BatchNormalization: 20
# Relu: 17
# MaxPool: 1
# Add: 8
# GlobalAveragePool: 1
# Flatten: 1
# Gemm: 1
# total operations: 69
# Model: resnet34-v1-7.onnx
#
# Layer Dimensions:
# 0 Conv Layer: Input Shape: [0, 3, 224, 224], weight: [64, 3, 7, 7], Output Shape: [0, 64, 112, 112], flops: 29503488.0
# 4 Conv Layer: Input Shape: [0, 64, 56, 56], weight: [64, 64, 3, 3], Output Shape: [0, 64, 56, 56], flops: 115605504.0
# 7 Conv Layer: Input Shape: [0, 64, 56, 56], weight: [64, 64, 3, 3], Output Shape: [0, 64, 56, 56], flops: 115605504.0
# 9 Add Layer: Input1 Shape: [0, 64, 56, 56], Input2 Shape: [0, 64, 56, 56], Output Shape: [0, 64, 56, 56], flops: 200704
# 11 Conv Layer: Input Shape: [0, 64, 56, 56], weight: [64, 64, 3, 3], Output Shape: [0, 64, 56, 56], flops: 115605504.0
# 14 Conv Layer: Input Shape: [0, 64, 56, 56], weight: [64, 64, 3, 3], Output Shape: [0, 64, 56, 56], flops: 115605504.0
# 16 Add Layer: Input1 Shape: [0, 64, 56, 56], Input2 Shape: [0, 64, 56, 56], Output Shape: [0, 64, 56, 56], flops: 200704
# 18 Conv Layer: Input Shape: [0, 64, 56, 56], weight: [64, 64, 3, 3], Output Shape: [0, 64, 56, 56], flops: 115605504.0
# 21 Conv Layer: Input Shape: [0, 64, 56, 56], weight: [64, 64, 3, 3], Output Shape: [0, 64, 56, 56], flops: 115605504.0
# 23 Add Layer: Input1 Shape: [0, 64, 56, 56], Input2 Shape: [0, 64, 56, 56], Output Shape: [0, 64, 56, 56], flops: 200704
# 25 Conv Layer: Input Shape: [0, 64, 56, 56], weight: [128, 64, 1, 1], Output Shape: [0, 128, 28, 28], flops: 1605632.0
# 27 Conv Layer: Input Shape: [0, 64, 56, 56], weight: [128, 64, 3, 3], Output Shape: [0, 128, 28, 28], flops: 14450688.0
# 30 Conv Layer: Input Shape: [0, 128, 28, 28], weight: [128, 128, 3, 3], Output Shape: [0, 128, 28, 28], flops: 115605504.0
# 32 Add Layer: Input1 Shape: [0, 128, 28, 28], Input2 Shape: [0, 128, 28, 28], Output Shape: [0, 128, 28, 28], flops: 100352
# 34 Conv Layer: Input Shape: [0, 128, 28, 28], weight: [128, 128, 3, 3], Output Shape: [0, 128, 28, 28], flops: 115605504.0
# 37 Conv Layer: Input Shape: [0, 128, 28, 28], weight: [128, 128, 3, 3], Output Shape: [0, 128, 28, 28], flops: 115605504.0
# 39 Add Layer: Input1 Shape: [0, 128, 28, 28], Input2 Shape: [0, 128, 28, 28], Output Shape: [0, 128, 28, 28], flops: 100352
# 41 Conv Layer: Input Shape: [0, 128, 28, 28], weight: [128, 128, 3, 3], Output Shape: [0, 128, 28, 28], flops: 115605504.0
# 44 Conv Layer: Input Shape: [0, 128, 28, 28], weight: [128, 128, 3, 3], Output Shape: [0, 128, 28, 28], flops: 115605504.0
# 46 Add Layer: Input1 Shape: [0, 128, 28, 28], Input2 Shape: [0, 128, 28, 28], Output Shape: [0, 128, 28, 28], flops: 100352
# 48 Conv Layer: Input Shape: [0, 128, 28, 28], weight: [128, 128, 3, 3], Output Shape: [0, 128, 28, 28], flops: 115605504.0
# 51 Conv Layer: Input Shape: [0, 128, 28, 28], weight: [128, 128, 3, 3], Output Shape: [0, 128, 28, 28], flops: 115605504.0
# 53 Add Layer: Input1 Shape: [0, 128, 28, 28], Input2 Shape: [0, 128, 28, 28], Output Shape: [0, 128, 28, 28], flops: 100352
# 55 Conv Layer: Input Shape: [0, 128, 28, 28], weight: [256, 128, 1, 1], Output Shape: [0, 256, 14, 14], flops: 1605632.0
# 57 Conv Layer: Input Shape: [0, 128, 28, 28], weight: [256, 128, 3, 3], Output Shape: [0, 256, 14, 14], flops: 14450688.0
# 60 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [256, 256, 3, 3], Output Shape: [0, 256, 14, 14], flops: 115605504.0
# 62 Add Layer: Input1 Shape: [0, 256, 14, 14], Input2 Shape: [0, 256, 14, 14], Output Shape: [0, 256, 14, 14], flops: 50176
# 64 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [256, 256, 3, 3], Output Shape: [0, 256, 14, 14], flops: 115605504.0
# 67 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [256, 256, 3, 3], Output Shape: [0, 256, 14, 14], flops: 115605504.0
# 69 Add Layer: Input1 Shape: [0, 256, 14, 14], Input2 Shape: [0, 256, 14, 14], Output Shape: [0, 256, 14, 14], flops: 50176
# 71 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [256, 256, 3, 3], Output Shape: [0, 256, 14, 14], flops: 115605504.0
# 74 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [256, 256, 3, 3], Output Shape: [0, 256, 14, 14], flops: 115605504.0
# 76 Add Layer: Input1 Shape: [0, 256, 14, 14], Input2 Shape: [0, 256, 14, 14], Output Shape: [0, 256, 14, 14], flops: 50176
# 78 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [256, 256, 3, 3], Output Shape: [0, 256, 14, 14], flops: 115605504.0
# 81 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [256, 256, 3, 3], Output Shape: [0, 256, 14, 14], flops: 115605504.0
# 83 Add Layer: Input1 Shape: [0, 256, 14, 14], Input2 Shape: [0, 256, 14, 14], Output Shape: [0, 256, 14, 14], flops: 50176
# 85 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [256, 256, 3, 3], Output Shape: [0, 256, 14, 14], flops: 115605504.0
# 88 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [256, 256, 3, 3], Output Shape: [0, 256, 14, 14], flops: 115605504.0
# 90 Add Layer: Input1 Shape: [0, 256, 14, 14], Input2 Shape: [0, 256, 14, 14], Output Shape: [0, 256, 14, 14], flops: 50176
# 92 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [256, 256, 3, 3], Output Shape: [0, 256, 14, 14], flops: 115605504.0
# 95 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [256, 256, 3, 3], Output Shape: [0, 256, 14, 14], flops: 115605504.0
# 97 Add Layer: Input1 Shape: [0, 256, 14, 14], Input2 Shape: [0, 256, 14, 14], Output Shape: [0, 256, 14, 14], flops: 50176
# 99 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [512, 256, 1, 1], Output Shape: [0, 512, 7, 7], flops: 1605632.0
# 101 Conv Layer: Input Shape: [0, 256, 14, 14], weight: [512, 256, 3, 3], Output Shape: [0, 512, 7, 7], flops: 14450688.0
# 104 Conv Layer: Input Shape: [0, 512, 7, 7], weight: [512, 512, 3, 3], Output Shape: [0, 512, 7, 7], flops: 115605504.0
# 106 Add Layer: Input1 Shape: [0, 512, 7, 7], Input2 Shape: [0, 512, 7, 7], Output Shape: [0, 512, 7, 7], flops: 25088
# 108 Conv Layer: Input Shape: [0, 512, 7, 7], weight: [512, 512, 3, 3], Output Shape: [0, 512, 7, 7], flops: 115605504.0
# 111 Conv Layer: Input Shape: [0, 512, 7, 7], weight: [512, 512, 3, 3], Output Shape: [0, 512, 7, 7], flops: 115605504.0
# ...
# 212 Conv Layer: Input Shape: [1, 232, 7, 7], weight: (232, 232, 1, 1), Output Shape: [1, 232, 7, 7], flops: 2637376.0
# 215 Conv Layer: Input Shape: [1, 232, 7, 7], weight: (232, 1, 3, 3), Output Shape: [1, 232, 7, 7], flops: 23736384.0
# 217 Conv Layer: Input Shape: [1, 232, 7, 7], weight: (232, 232, 1, 1), Output Shape: [1, 232, 7, 7], flops: 2637376.0
# 227 Conv Layer: Input Shape: [1, 232, 7, 7], weight: (232, 232, 1, 1), Output Shape: [1, 232, 7, 7], flops: 2637376.0
# 230 Conv Layer: Input Shape: [1, 232, 7, 7], weight: (232, 1, 3, 3), Output Shape: [1, 232, 7, 7], flops: 23736384.0
# 232 Conv Layer: Input Shape: [1, 232, 7, 7], weight: (232, 232, 1, 1), Output Shape: [1, 232, 7, 7], flops: 2637376.0
# 242 Conv Layer: Input Shape: [1, 232, 7, 7], weight: (232, 232, 1, 1), Output Shape: [1, 232, 7, 7], flops: 2637376.0
# 245 Conv Layer: Input Shape: [1, 232, 7, 7], weight: (232, 1, 3, 3), Output Shape: [1, 232, 7, 7], flops: 23736384.0
# 247 Conv Layer: Input Shape: [1, 232, 7, 7], weight: (232, 232, 1, 1), Output Shape: [1, 232, 7, 7], flops: 2637376.0
# 256 Conv Layer: Input Shape: [1, 464, 7, 7], weight: (1024, 464, 1, 1), Output Shape: [1, 1024, 7, 7], flops: 23281664.0
# 260 Gemm 611 Layer: Input Shape: [1, 1024], weight: (1000, 1024), Output Shape: [1, 1000], flops: 1048576000
# model summary: /content/gdrive/MyDrive/ONNXAnalyser/onnx_models/shufflenet-v2-10.onnx
# Conv: 56
# BatchNormalization: 56
# Relu: 37
# MaxPool: 1
# Concat: 16
# Constant: 32
# Reshape: 32
# Transpose: 16
# Split: 13
# ReduceMean: 1
# Gemm: 1
# total operations: 261
# Model: efficientnet-lite4-11.onnx
#
# Layer Dimensions:
# 1 Conv Layer: Input Shape: [1, 3, 224, 224], weight: (32, 3, 3, 3), Output Shape: [1, 32, 112, 112], flops: 2709504.0
# 3 Conv Layer: Input Shape: [1, 32, 112, 112], weight: (32, 1, 3, 3), Output Shape: [1, 32, 112, 112], flops: 115605504.0
# 5 Conv Layer: Input Shape: [1, 32, 112, 112], weight: (24, 32, 1, 1), Output Shape: [1, 24, 112, 112], flops: 9633792.0
# 6 Conv Layer: Input Shape: [1, 24, 112, 112], weight: (144, 24, 1, 1), Output Shape: [1, 144, 112, 112], flops: 43352064.0
# 9 Conv Layer: Input Shape: [1, 144, 112, 112], weight: (144, 1, 3, 3), Output Shape: [1, 144, 56, 56], flops: 146313216.0
# 11 Conv Layer: Input Shape: [1, 144, 56, 56], weight: (32, 144, 1, 1), Output Shape: [1, 32, 56, 56], flops: 14450688.0
# 12 Conv Layer: Input Shape: [1, 32, 56, 56], weight: (192, 32, 1, 1), Output Shape: [1, 192, 56, 56], flops: 19267584.0
# 15 Conv Layer: Input Shape: [1, 192, 56, 56], weight: (192, 1, 3, 3), Output Shape: [1, 192, 56, 56], flops: 1040449536.0
# 17 Conv Layer: Input Shape: [1, 192, 56, 56], weight: (32, 192, 1, 1), Output Shape: [1, 32, 56, 56], flops: 19267584.0
# 18 Add Layer: Input1 Shape: [1, 32, 56, 56], Input2 Shape: [1, 32, 56, 56], Output Shape: [1, 32, 56, 56], flops: 602112
# 19 Conv Layer: Input Shape: [1, 32, 56, 56], weight: (192, 32, 1, 1), Output Shape: [1, 192, 56, 56], flops: 19267584.0
# 21 Conv Layer: Input Shape: [1, 192, 56, 56], weight: (192, 1, 3, 3), Output Shape: [1, 192, 56, 56], flops: 1040449536.0
# 23 Conv Layer: Input Shape: [1, 192, 56, 56], weight: (32, 192, 1, 1), Output Shape: [1, 32, 56, 56], flops: 19267584.0
# 24 Add Layer: Input1 Shape: [1, 32, 56, 56], Input2 Shape: [1, 32, 56, 56], Output Shape: [1, 32, 56, 56], flops: 602112
# 25 Conv Layer: Input Shape: [1, 32, 56, 56], weight: (192, 32, 1, 1), Output Shape: [1, 192, 56, 56], flops: 19267584.0
# 27 Conv Layer: Input Shape: [1, 192, 56, 56], weight: (192, 1, 3, 3), Output Shape: [1, 192, 56, 56], flops: 1040449536.0
# 29 Conv Layer: Input Shape: [1, 192, 56, 56], weight: (32, 192, 1, 1), Output Shape: [1, 32, 56, 56], flops: 19267584.0
# 30 Add Layer: Input1 Shape: [1, 32, 56, 56], Input2 Shape: [1, 32, 56, 56], Output Shape: [1, 32, 56, 56], flops: 602112
# 31 Conv Layer: Input Shape: [1, 32, 56, 56], weight: (192, 32, 1, 1), Output Shape: [1, 192, 56, 56], flops: 19267584.0
# 33 Conv Layer: Input Shape: [1, 192, 56, 56], weight: (192, 1, 5, 5), Output Shape: [1, 192, 28, 28], flops: 180633600.0
# 35 Conv Layer: Input Shape: [1, 192, 28, 28], weight: (56, 192, 1, 1), Output Shape: [1, 56, 28, 28], flops: 8429568.0
# 36 Conv Layer: Input Shape: [1, 56, 28, 28], weight: (336, 56, 1, 1), Output Shape: [1, 336, 28, 28], flops: 14751744.0
# 39 Conv Layer: Input Shape: [1, 336, 28, 28], weight: (336, 1, 5, 5), Output Shape: [1, 336, 28, 28], flops: 2212761600.0
# 41 Conv Layer: Input Shape: [1, 336, 28, 28], weight: (56, 336, 1, 1), Output Shape: [1, 56, 28, 28], flops: 14751744.0
# 42 Add Layer: Input1 Shape: [1, 56, 28, 28], Input2 Shape: [1, 56, 28, 28], Output Shape: [1, 56, 28, 28], flops: 263424
# 43 Conv Layer: Input Shape: [1, 56, 28, 28], weight: (336, 56, 1, 1), Output Shape: [1, 336, 28, 28], flops: 14751744.0
# 45 Conv Layer: Input Shape: [1, 336, 28, 28], weight: (336, 1, 5, 5), Output Shape: [1, 336, 28, 28], flops: 2212761600.0
# 47 Conv Layer: Input Shape: [1, 336, 28, 28], weight: (56, 336, 1, 1), Output Shape: [1, 56, 28, 28], flops: 14751744.0
# 48 Add Layer: Input1 Shape: [1, 56, 28, 28], Input2 Shape: [1, 56, 28, 28], Output Shape: [1, 56, 28, 28], flops: 263424
# 49 Conv Layer: Input Shape: [1, 56, 28, 28], weight: (336, 56, 1, 1), Output Shape: [1, 336, 28, 28], flops: 14751744.0
# 51 Conv Layer: Input Shape: [1, 336, 28, 28], weight: (336, 1, 5, 5), Output Shape: [1, 336, 28, 28], flops: 2212761600.0
# 53 Conv Layer: Input Shape: [1, 336, 28, 28], weight: (56, 336, 1, 1), Output Shape: [1, 56, 28, 28], flops: 14751744.0
# 54 Add Layer: Input1 Shape: [1, 56, 28, 28], Input2 Shape: [1, 56, 28, 28], Output Shape: [1, 56, 28, 28], flops: 263424
# 55 Conv Layer: Input Shape: [1, 56, 28, 28], weight: (336, 56, 1, 1), Output Shape: [1, 336, 28, 28], flops: 14751744.0
# 57 Conv Layer: Input Shape: [1, 336, 28, 28], weight: (336, 1, 3, 3), Output Shape: [1, 336, 14, 14], flops: 49787136.0
# 59 Conv Layer: Input Shape: [1, 336, 14, 14], weight: (112, 336, 1, 1), Output Shape: [1, 112, 14, 14], flops: 7375872.0
# 60 Conv Layer: Input Shape: [1, 112, 14, 14], weight: (672, 112, 1, 1), Output Shape: [1, 672, 14, 14], flops: 14751744.0
# 63 Conv Layer: Input Shape: [1, 672, 14, 14], weight: (672, 1, 3, 3), Output Shape: [1, 672, 14, 14], flops: 796594176.0
# 65 Conv Layer: Input Shape: [1, 672, 14, 14], weight: (112, 672, 1, 1), Output Shape: [1, 112, 14, 14], flops: 14751744.0
# 66 Add Layer: Input1 Shape: [1, 112, 14, 14], Input2 Shape: [1, 112, 14, 14], Output Shape: [1, 112, 14, 14], flops: 131712
# 67 Conv Layer: Input Shape: [1, 112, 14, 14], weight: (672, 112, 1, 1), Output Shape: [1, 672, 14, 14], flops: 14751744.0
# 69 Conv Layer: Input Shape: [1, 672, 14, 14], weight: (672, 1, 3, 3), Output Shape: [1, 672, 14, 14], flops: 796594176.0
# 71 Conv Layer: Input Shape: [1, 672, 14, 14], weight: (112, 672, 1, 1), Output Shape: [1, 112, 14, 14], flops: 14751744.0
# 72 Add Layer: Input1 Shape: [1, 112, 14, 14], Input2 Shape: [1, 112, 14, 14], Output Shape: [1, 112, 14, 14], flops: 131712
# 73 Conv Layer: Input Shape: [1, 112, 14, 14], weight: (672, 112, 1, 1), Output Shape: [1, 672, 14, 14], flops: 14751744.0
# 75 Conv Layer: Input Shape: [1, 672, 14, 14], weight: (672, 1, 3, 3), Output Shape: [1, 672, 14, 14], flops: 796594176.0
# 77 Conv Layer: Input Shape: [1, 672, 14, 14], weight: (112, 672, 1, 1), Output Shape: [1, 112, 14, 14], flops: 14751744.0
# 78 Add Layer: Input1 Shape: [1, 112, 14, 14], Input2 Shape: [1, 112, 14, 14], Output Shape: [1, 112, 14, 14], flops: 131712
# 79 Conv Layer: Input Shape: [1, 112, 14, 14], weight: (672, 112, 1, 1), Output Shape: [1, 672, 14, 14], flops: 14751744.0
# 81 Conv Layer: Input Shape: [1, 672, 14, 14], weight: (672, 1, 3, 3), Output Shape: [1, 672, 14, 14], flops: 796594176.0
# 83 Conv Layer: Input Shape: [1, 672, 14, 14], weight: (112, 672, 1, 1), Output Shape: [1, 112, 14, 14], flops: 14751744.0
# 84 Add Layer: Input1 Shape: [1, 112, 14, 14], Input2 Shape: [1, 112, 14, 14], Output Shape: [1, 112, 14, 14], flops: 131712
# 85 Conv Layer: Input Shape: [1, 112, 14, 14], weight: (672, 112, 1, 1), Output Shape: [1, 672, 14, 14], flops: 14751744.0
# 87 Conv Layer: Input Shape: [1, 672, 14, 14], weight: (672, 1, 3, 3), Output Shape: [1, 672, 14, 14], flops: 796594176.0
# 89 Conv Layer: Input Shape: [1, 672, 14, 14], weight: (112, 672, 1, 1), Output Shape: [1, 112, 14, 14], flops: 14751744.0
# 90 Add Layer: Input1 Shape: [1, 112, 14, 14], Input2 Shape: [1, 112, 14, 14], Output Shape: [1, 112, 14, 14], flops: 131712
# 91 Conv Layer: Input Shape: [1, 112, 14, 14], weight: (672, 112, 1, 1), Output Shape: [1, 672, 14, 14], flops: 14751744.0
# 93 Conv Layer: Input Shape: [1, 672, 14, 14], weight: (672, 1, 5, 5), Output Shape: [1, 672, 14, 14], flops: 2212761600.0
# 95 Conv Layer: Input Shape: [1, 672, 14, 14], weight: (160, 672, 1, 1), Output Shape: [1, 160, 14, 14], flops: 21073920.0
# 96 Conv Layer: Input Shape: [1, 160, 14, 14], weight: (960, 160, 1, 1), Output Shape: [1, 960, 14, 14], flops: 30105600.0
# 99 Conv Layer: Input Shape: [1, 960, 14, 14], weight: (960, 1, 5, 5), Output Shape: [1, 960, 14, 14], flops: 4515840000.0
# 101 Conv Layer: Input Shape: [1, 960, 14, 14], weight: (160, 960, 1, 1), Output Shape: [1, 160, 14, 14], flops: 30105600.0
# 102 Add Layer: Input1 Shape: [1, 160, 14, 14], Input2 Shape: [1, 160, 14, 14], Output Shape: [1, 160, 14, 14], flops: 188160
# 103 Conv Layer: Input Shape: [1, 160, 14, 14], weight: (960, 160, 1, 1), Output Shape: [1, 960, 14, 14], flops: 30105600.0
# 105 Conv Layer: Input Shape: [1, 960, 14, 14], weight: (960, 1, 5, 5), Output Shape: [1, 960, 14, 14], flops: 4515840000.0
# 107 Conv Layer: Input Shape: [1, 960, 14, 14], weight: (160, 960, 1, 1), Output Shape: [1, 160, 14, 14], flops: 30105600.0
# 108 Add Layer: Input1 Shape: [1, 160, 14, 14], Input2 Shape: [1, 160, 14, 14], Output Shape: [1, 160, 14, 14], flops: 188160
# 109 Conv Layer: Input Shape: [1, 160, 14, 14], weight: (960, 160, 1, 1), Output Shape: [1, 960, 14, 14], flops: 30105600.0
# 111 Conv Layer: Input Shape: [1, 960, 14, 14], weight: (960, 1, 5, 5), Output Shape: [1, 960, 14, 14], flops: 4515840000.0
# 113 Conv Layer: Input Shape: [1, 960, 14, 14], weight: (160, 960, 1, 1), Output Shape: [1, 160, 14, 14], flops: 30105600.0
# 114 Add Layer: Input1 Shape: [1, 160, 14, 14], Input2 Shape: [1, 160, 14, 14], Output Shape: [1, 160, 14, 14], flops: 188160
# 115 Conv Layer: Input Shape: [1, 160, 14, 14], weight: (960, 160, 1, 1), Output Shape: [1, 960, 14, 14], flops: 30105600.0
# 117 Conv Layer: Input Shape: [1, 960, 14, 14], weight: (960, 1, 5, 5), Output Shape: [1, 960, 14, 14], flops: 4515840000.0
# 119 Conv Layer: Input Shape: [1, 960, 14, 14], weight: (160, 960, 1, 1), Output Shape: [1, 160, 14, 14], flops: 30105600.0
# 120 Add Layer: Input1 Shape: [1, 160, 14, 14], Input2 Shape: [1, 160, 14, 14], Output Shape: [1, 160, 14, 14], flops: 188160
# 121 Conv Layer: Input Shape: [1, 160, 14, 14], weight: (960, 160, 1, 1), Output Shape: [1, 960, 14, 14], flops: 30105600.0
# 123 Conv Layer: Input Shape: [1, 960, 14, 14], weight: (960, 1, 5, 5), Output Shape: [1, 960, 14, 14], flops: 4515840000.0
# 125 Conv Layer: Input Shape: [1, 960, 14, 14], weight: (160, 960, 1, 1), Output Shape: [1, 160, 14, 14], flops: 30105600.0
# 126 Add Layer: Input1 Shape: [1, 160, 14, 14], Input2 Shape: [1, 160, 14, 14], Output Shape: [1, 160, 14, 14], flops: 188160
# 127 Conv Layer: Input Shape: [1, 160, 14, 14], weight: (960, 160, 1, 1), Output Shape: [1, 960, 14, 14], flops: 30105600.0
# 129 Conv Layer: Input Shape: [1, 960, 14, 14], weight: (960, 1, 5, 5), Output Shape: [1, 960, 7, 7], flops: 282240000.0
# 131 Conv Layer: Input Shape: [1, 960, 7, 7], weight: (272, 960, 1, 1), Output Shape: [1, 272, 7, 7], flops: 12794880.0
# 132 Conv Layer: Input Shape: [1, 272, 7, 7], weight: (1632, 272, 1, 1), Output Shape: [1, 1632, 7, 7], flops: 21751296.0
# 135 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (1632, 1, 5, 5), Output Shape: [1, 1632, 7, 7], flops: 3262694400.0
# 137 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (272, 1632, 1, 1), Output Shape: [1, 272, 7, 7], flops: 21751296.0
# 138 Add Layer: Input1 Shape: [1, 272, 7, 7], Input2 Shape: [1, 272, 7, 7], Output Shape: [1, 272, 7, 7], flops: 79968
# 139 Conv Layer: Input Shape: [1, 272, 7, 7], weight: (1632, 272, 1, 1), Output Shape: [1, 1632, 7, 7], flops: 21751296.0
# 141 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (1632, 1, 5, 5), Output Shape: [1, 1632, 7, 7], flops: 3262694400.0
# 143 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (272, 1632, 1, 1), Output Shape: [1, 272, 7, 7], flops: 21751296.0
# 144 Add Layer: Input1 Shape: [1, 272, 7, 7], Input2 Shape: [1, 272, 7, 7], Output Shape: [1, 272, 7, 7], flops: 79968
# 145 Conv Layer: Input Shape: [1, 272, 7, 7], weight: (1632, 272, 1, 1), Output Shape: [1, 1632, 7, 7], flops: 21751296.0
# 147 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (1632, 1, 5, 5), Output Shape: [1, 1632, 7, 7], flops: 3262694400.0
# 149 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (272, 1632, 1, 1), Output Shape: [1, 272, 7, 7], flops: 21751296.0
# 150 Add Layer: Input1 Shape: [1, 272, 7, 7], Input2 Shape: [1, 272, 7, 7], Output Shape: [1, 272, 7, 7], flops: 79968
# 151 Conv Layer: Input Shape: [1, 272, 7, 7], weight: (1632, 272, 1, 1), Output Shape: [1, 1632, 7, 7], flops: 21751296.0
# 153 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (1632, 1, 5, 5), Output Shape: [1, 1632, 7, 7], flops: 3262694400.0
# 155 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (272, 1632, 1, 1), Output Shape: [1, 272, 7, 7], flops: 21751296.0
# 156 Add Layer: Input1 Shape: [1, 272, 7, 7], Input2 Shape: [1, 272, 7, 7], Output Shape: [1, 272, 7, 7], flops: 79968
# 157 Conv Layer: Input Shape: [1, 272, 7, 7], weight: (1632, 272, 1, 1), Output Shape: [1, 1632, 7, 7], flops: 21751296.0
# 159 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (1632, 1, 5, 5), Output Shape: [1, 1632, 7, 7], flops: 3262694400.0
# 161 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (272, 1632, 1, 1), Output Shape: [1, 272, 7, 7], flops: 21751296.0
# 162 Add Layer: Input1 Shape: [1, 272, 7, 7], Input2 Shape: [1, 272, 7, 7], Output Shape: [1, 272, 7, 7], flops: 79968
# 163 Conv Layer: Input Shape: [1, 272, 7, 7], weight: (1632, 272, 1, 1), Output Shape: [1, 1632, 7, 7], flops: 21751296.0
# 165 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (1632, 1, 5, 5), Output Shape: [1, 1632, 7, 7], flops: 3262694400.0
# 167 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (272, 1632, 1, 1), Output Shape: [1, 272, 7, 7], flops: 21751296.0
# 168 Add Layer: Input1 Shape: [1, 272, 7, 7], Input2 Shape: [1, 272, 7, 7], Output Shape: [1, 272, 7, 7], flops: 79968
# 169 Conv Layer: Input Shape: [1, 272, 7, 7], weight: (1632, 272, 1, 1), Output Shape: [1, 1632, 7, 7], flops: 21751296.0
# 171 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (1632, 1, 5, 5), Output Shape: [1, 1632, 7, 7], flops: 3262694400.0
# 173 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (272, 1632, 1, 1), Output Shape: [1, 272, 7, 7], flops: 21751296.0
# 174 Add Layer: Input1 Shape: [1, 272, 7, 7], Input2 Shape: [1, 272, 7, 7], Output Shape: [1, 272, 7, 7], flops: 79968
# 175 Conv Layer: Input Shape: [1, 272, 7, 7], weight: (1632, 272, 1, 1), Output Shape: [1, 1632, 7, 7], flops: 21751296.0
# 177 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (1632, 1, 3, 3), Output Shape: [1, 1632, 7, 7], flops: 1174569984.0
# 179 Conv Layer: Input Shape: [1, 1632, 7, 7], weight: (448, 1632, 1, 1), Output Shape: [1, 448, 7, 7], flops: 35825664.0
# 180 Conv Layer: Input Shape: [1, 448, 7, 7], weight: (1280, 448, 1, 1), Output Shape: [1, 1280, 7, 7], flops: 28098560.0
# 183 AveragePool efficientnet-lite4/model/head/Relu6:0 Layer: Input Shape: [1, 1280, 7, 7], Output Shape: [1, 1280, 1, 1], flops: 62720
# 185 MatMul Layer: Input1 Shape: [1, 1280], Input2 Shape: (1280, 1000), Output Shape: [1, 1000], flops: 1280000
# 186 Add Layer: Input1 Shape: [1, 1000], Input2 Shape: (1000,), Output Shape: [1, 1000], flops: 62720
# model summary: /content/gdrive/MyDrive/ONNXAnalyser/onnx_models/efficientnet-lite4-11.onnx
# Transpose: 1
# Conv: 91
# Clip: 61
# BatchNormalization: 7
# Add: 24
# AveragePool: 1
# Squeeze: 1
# MatMul: 1
# Softmax: 1
# total operations: 188

# %%
import pickle as pkl
file_path = workspace + '/compute_estimates.pkl'  # Replace with the desired file path

# Open the file in binary mode for writing
with open(file_path, 'wb') as file:
    pkl.dump(compute_estimate, file)

# %%
import pickle as pkl
file_path = workspace + '/compute_estimates.pkl'  # Replace with the desired file path

# Open the file in binary mode for writing
with open(file_path, 'rb') as file:
    compute_estimate = pkl.load(file)

# %%
import plotly.graph_objects as go
from plotly.offline import plot
# Extract keys and values from the dictionary
categories = list(compute_estimate.keys())
counts = list(compute_estimate.values())

# Create a bar trace for the histogram
trace = go.Bar(x=categories, y=counts)

# Create the layout for the histogram
layout = go.Layout(title={'text': 'Network Architecture vs FLOPs',
                          'x': 0.5,  # Align title to the center horizontally
                   },
                   xaxis=dict(title='Network Architecture'),
                   yaxis=dict(title='FLOPs',
                   type='log'))

# Create the figure and add the trace
fig = go.Figure(data=[trace], layout=layout)

# Show the figure
fig.show()
fig.write_image('compute.jpg')
fig.write_html('image.html')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="724a8a76-baf5-4fcf-bca5-bc82fb9e0fc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("724a8a76-baf5-4fcf-bca5-bc82fb9e0fc6")) {                    Plotly.newPlot(                        "724a8a76-baf5-4fcf-bca5-bc82fb9e0fc6",                        [{"type": "bar", "x": ["bvlcalexnet-12", "vgg16-12", "vgg19-7", "inception-v1-12", "inception-v2-9", "googlenet-12", "resnet18-v1-7", "resnet34-v1-7", "resnet50-v1-7", "resnet101-v1-7", "resnet152-v1-7", "densenet-9", "squeezenet1.0-12", "mobilenetv2-7", "shufflenet-v2-10", "efficientnet-lite4-11"], "y": [434256636104.0, 2678897442816.0, 2683059240960.0, 2390597888.0, 2915588896.0, 2541713408.0, 1843465728.0, 3693780992.0, 7675414528.0, 11388488704.0, 15101763584.0, 2760114432.0, 333352920.0, 7590732416.0, 1521463632.0, 64570317344.0]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"o ...

# %%
# !pip install kaleido
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaleido in /usr/local/lib/python3.10/dist-packages (0.2.1)

# %%
import pickle as pkl
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go

compute_path = workspace + '/compute_estimates.pkl'  # Replace with the desired file path
memory_path = workspace + '/memory_estimates.pkl'  # Replace with the desired file path

# Load the compute data from pickle file
with open(compute_path, 'rb') as file:
    compute_data = pkl.load(file)

# Load the memory data from pickle file
with open(memory_path, 'rb') as file:
    memory_data = pkl.load(file)

# Extract x and y values from dictionaries
x = list(compute_data.values())
y = list(memory_data.values())
labels = list(compute_data.keys())  # Use keys as labels

# Create the graph
fig = go.Figure()

# Plotting the scatter plot
for i in range(len(x)):
    fig.add_trace(go.Scatter(x=[x[i]], y=[y[i]], mode='markers', name=labels[i],marker=dict(size=15, symbol=i)))

# # Plotting the scatter plot
# fig.add_trace(go.Scatter(x=x, y=y, mode='markers', text=labels))

# Customize the layout
fig.update_layout(
    title={
        'text': 'Compute (FLOPs) vs Memory Bandwidth',
        'x': 0.5,  # Align title to the center horizontally
    },
    xaxis_title='Compute (FLOPs)',
    yaxis_title='Memory Bandwidth/Inference',
    xaxis_type='log',  # Set x-axis to log scale
    showlegend=True,  # Display legend
)

# Display the graph
fig.show()
fig.write_image('compute_vs_bandwidth.jpg')
fig.write_html('image.html')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="44876b69-b12e-4f40-bcda-3011a502a198" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44876b69-b12e-4f40-bcda-3011a502a198")) {                    Plotly.newPlot(                        "44876b69-b12e-4f40-bcda-3011a502a198",                        [{"marker": {"size": 15, "symbol": 0}, "mode": "markers", "name": "bvlcalexnet-12", "type": "scatter", "x": [434256636104.0], "y": [3601312]}, {"marker": {"size": 15, "symbol": 1}, "mode": "markers", "name": "vgg16-12", "type": "scatter", "x": [2678897442816.0], "y": [30257104]}, {"marker": {"size": 15, "symbol": 2}, "mode": "markers", "name": "vgg19-7", "type": "scatter", "x": [2683059240960.0], "y": [32866256]}, {"marker": {"size": 15, "symbol": 3}, "mode": "markers", "name": "inception-v1-12", "type": "scatter", "x": [2390597888.0], "y": [20369184]}, {"marker": {"size": 15, "symbol": 4}, "mode": "markers", "name": "inception-v2-9", "type": "scatter", "x": [2915588896.0], "y": [42311776]}, {"marker": {"size": 15, "symbol": 5}, "mode": "markers", "name": "googlenet-12", "type": "scatter", "x": [2541713408.0], "y": [19826528]}, {"marker": {"size": 15, "symbol": 6}, "mode": "markers", "name": "resnet18-v1-7", "type": "scatter", "x": [1843465728.0], "y": [8383440]}, {"marker": {"size": 15, "symbol": 7}, "mode": "markers", "name": "resnet34-v1-7", "type": "scatter", "x": [3693780992.0], "y": [13401040]}, {"marker": {"size": 15, "symbol": 8}, "mode": "markers", "name": "resnet50-v1-7", "type": "scatter", "x": [7675414528.0], "y": [43663312]}, {"marker": {"size": 15, "symbol": 9}, "mode": "markers", "name": "resnet101-v1-7", "type": "scatter", "x": [11388488704.0], "y": [67547088]}, {"marker": {"size": 15, "symbol": 10}, "mode": "markers", "name": "resnet152-v1-7", "type": "scatter", "x": [15101763584.0], "y": [97050576]}, {"marker": {"size": 15, "symbol": 11}, "mode": "markers", "name": "densenet-9", "type": "scatter", "x": [2760114432.0], "y": [160408400]}, {"marker": {"size": 15, "symbol": 12}, "mode": "markers", "name": "squeezenet1.0-12", "type": "scatter", "x": [333352920.0], "y": [14095808]}, {"marker": {"size": 15, "symbol": 13}, "mode": "markers", "name": "mobilenetv2-7", "type": "scatter", "x": [7590732416.0], "y": [18512096]}, {"marker": {"size": 15, "symbol": 14}, "mode": "markers", "name": "shufflenet-v2-10", "type": "scatter", "x": [1521463632.0], "y": [18139040]}, {"marker": {"size": 15, "symbol": 15}, "mode": "markers", "name": "efficientnet-lite4-11", "type": "scatter", "x": [64570317344.0], "y": [68321040]}],                        {"showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "he ...

# %%
import pickle as pkl
import plotly.graph_objects as go

compute_path = workspace + '/compute_estimates.pkl'  # Replace with the desired file path
memory_path = workspace + '/memory_estimates.pkl'  # Replace with the desired file path

# Load the compute data from the pickle file
with open(compute_path, 'rb') as file:
    compute_data = pkl.load(file)

# Load the memory data from the pickle file
with open(memory_path, 'rb') as file:
    memory_data = pkl.load(file)

# Extract x and y values from dictionaries
x = list(compute_data.values())
y = list(memory_data.values())
labels = list(compute_data.keys())  # Use keys as labels

# Create the graph
fig = go.Figure()

# Plotting the scatter plot with adjusted text position
for i in range(len(x)):
    fig.add_trace(go.Scatter(
        x=[x[i]],
        y=[y[i]],
        mode='markers+text',
        name=labels[i],
        text=[labels[i]],
        textposition='bottom right',  # Adjust text position relative to markers
        marker=dict(size=15, symbol=i)
    ))

# Customize the layout
fig.update_layout(
    title={
        'text': 'Compute (FLOPs) vs Memory Bandwidth',
        'x': 0.5,  # Align title to the center horizontally
    },
    xaxis_title='Compute (FLOPs)',
    yaxis_title='Memory Bandwidth/Inference',
    xaxis_type='log',  # Set x-axis to log scale
    showlegend=True,  # Display legend
)

# Display the graph
fig.show()
# Set larger image dimensions and write the image
image_width = 4800
image_height = 1200
fig.write_image('compute_vs_bandwidth.jpg')
fig.write_html('image.html')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="a51db46b-ae61-430c-887e-1ab79ed896f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a51db46b-ae61-430c-887e-1ab79ed896f4")) {                    Plotly.newPlot(                        "a51db46b-ae61-430c-887e-1ab79ed896f4",                        [{"marker": {"size": 15, "symbol": 0}, "mode": "markers+text", "name": "bvlcalexnet-12", "text": ["bvlcalexnet-12"], "textposition": "bottom right", "type": "scatter", "x": [434256636104.0], "y": [3601312]}, {"marker": {"size": 15, "symbol": 1}, "mode": "markers+text", "name": "vgg16-12", "text": ["vgg16-12"], "textposition": "bottom right", "type": "scatter", "x": [2678897442816.0], "y": [30257104]}, {"marker": {"size": 15, "symbol": 2}, "mode": "markers+text", "name": "vgg19-7", "text": ["vgg19-7"], "textposition": "bottom right", "type": "scatter", "x": [2683059240960.0], "y": [32866256]}, {"marker": {"size": 15, "symbol": 3}, "mode": "markers+text", "name": "inception-v1-12", "text": ["inception-v1-12"], "textposition": "bottom right", "type": "scatter", "x": [2390597888.0], "y": [20369184]}, {"marker": {"size": 15, "symbol": 4}, "mode": "markers+text", "name": "inception-v2-9", "text": ["inception-v2-9"], "textposition": "bottom right", "type": "scatter", "x": [2915588896.0], "y": [42311776]}, {"marker": {"size": 15, "symbol": 5}, "mode": "markers+text", "name": "googlenet-12", "text": ["googlenet-12"], "textposition": "bottom right", "type": "scatter", "x": [2541713408.0], "y": [19826528]}, {"marker": {"size": 15, "symbol": 6}, "mode": "markers+text", "name": "resnet18-v1-7", "text": ["resnet18-v1-7"], "textposition": "bottom right", "type": "scatter", "x": [1843465728.0], "y": [8383440]}, {"marker": {"size": 15, "symbol": 7}, "mode": "markers+text", "name": "resnet34-v1-7", "text": ["resnet34-v1-7"], "textposition": "bottom right", "type": "scatter", "x": [3693780992.0], "y": [13401040]}, {"marker": {"size": 15, "symbol": 8}, "mode": "markers+text", "name": "resnet50-v1-7", "text": ["resnet50-v1-7"], "textposition": "bottom right", "type": "scatter", "x": [7675414528.0], "y": [43663312]}, {"marker": {"size": 15, "symbol": 9}, "mode": "markers+text", "name": "resnet101-v1-7", "text": ["resnet101-v1-7"], "textposition": "bottom right", "type": "scatter", "x": [11388488704.0], "y": [67547088]}, {"marker": {"size": 15, "symbol": 10}, "mode": "markers+text", "name": "resnet152-v1-7", "text": ["resnet152-v1-7"], "textposition": "bottom right", "type": "scatter", "x": [15101763584.0], "y": [97050576]}, {"marker": {"size": 15, "symbol": 11}, "mode": "markers+text", "name": "densenet-9", "text": ["densenet-9"], "textposition": "bottom right", "type": "scatter", "x": [2760114432.0], "y": [160408400]}, {"marker": {"size": 15, "symbol": 12}, "mode": "markers+text", "name": "squeezenet1.0-12", "text": ["squeezenet1.0-12"], "textposition": "bottom right", "type": "scatter", "x": [333352920.0], "y": [14095808]}, {"marker": {"size": 15, "symbol": 13}, "mode": "markers+text", "name": "mobilenetv2-7", "text": ["mobilenetv2-7"], "textposition": "bottom right", "type": "scatter", "x": [7590732416.0], "y": [18512096]}, {"marker": {"size": 15, "symbol": 14}, "mode": "markers+text", "name": "shufflenet-v2-10", "text": ["shufflenet-v2-10"], "textposition": "bottom right", "type": "scatter", "x": [1521463632.0], "y": [18139040]}, {"marker": {"size": 15, "symbol": 15}, "mode": "markers+text", "name": "efficientnet-lite4-11", "text": ["efficientnet-lite4-11"], "textposition": "bottom right", "type": "scatter", "x": [64570317344.0], "y": [68321040]}],                        {"showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {" ...
